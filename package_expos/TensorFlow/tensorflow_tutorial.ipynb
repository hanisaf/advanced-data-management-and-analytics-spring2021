# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      63   try:
# ---> 64     from tensorflow.python._pywrap_tensorflow_internal import *
#      65   # This try catch logic is because there is no bazel equivalent for py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8e94e9acb8d4> in <module>
#       1 import pandas as pd
#       2 from sklearn.model_selection import train_test_split
# ----> 3 from tensorflow.keras.models import Sequential, load_model
#       4 from tensorflow.keras.layers import Dense
#       5 from sklearn.metrics import accuracy_score
#
# ~\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      37 # go/tf-wildcard-import
#      38 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
# ---> 39 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      40
#      41 from tensorflow.python.eager import context
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      81 for some common reasons and solutions.  Include the entire stack trace
#      82 above this error message when asking for help.""" % traceback.format_exc()
# ---> 83   raise ImportError(msg)
#      84
#      85 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\tanne\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 64, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: The specified module could not be found.
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %% [markdown]
# ## Import Data

# %%
data = pd.read_csv('Churn.csv')

# %%
data.head(10)
# Out:
#   Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0  7590-VHVEA  Female               0     Yes         No       1
# 1  7590-VHVEG  Female               0     Yes         No       1
# 2  5575-GNVDE    Male               0      No         No      34
# 3  3668-QPYBK    Male               0      No         No       2
# 4  7795-CFOCW    Male               0      No         No      45
# 5  9237-HQITU  Female               0      No         No       2
# 6  9305-CDSKC  Female               0      No         No       8
# 7  1452-KIOVK    Male               0      No        Yes      22
# 8  6713-OKOMC  Female               0      No         No      10
# 9  7892-POOKP  Female               0     Yes         No      28
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1            No  No phone service              DSL              No  ...
# 2           Yes                No              DSL             Yes  ...
# 3           Yes                No              DSL             Yes  ...
# 4            No  No phone service              DSL             Yes  ...
# 5           Yes                No      Fiber optic              No  ...
# 6           Yes               Yes      Fiber optic              No  ...
# 7           Yes               Yes      Fiber optic              No  ...
# 8            No  No phone service              DSL             Yes  ...
# 9           Yes               Yes      Fiber optic              No  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1                No           No           No               No
# 2               Yes           No           No               No
# 3                No           No           No               No
# 4               Yes          Yes           No               No
# 5                No           No           No               No
# 6               Yes           No          Yes              Yes
# 7                No           No          Yes               No
# 8                No           No           No               No
# 9               Yes          Yes          Yes              Yes
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes           Electronic check
# 1  Month-to-month               Yes           Electronic check
# 2        One year                No               Mailed check
# 3  Month-to-month               Yes               Mailed check
# 4        One year                No  Bank transfer (automatic)
# 5  Month-to-month               Yes           Electronic check
# 6  Month-to-month               Yes           Electronic check
# 7  Month-to-month               Yes    Credit card (automatic)
# 8  Month-to-month                No               Mailed check
# 9  Month-to-month               Yes           Electronic check
#
#   Monthly Charges  Total Charges Churn
# 0           29.85          29.85    No
# 1           29.85          29.85    No
# 2           56.95         1889.5    No
# 3           53.85         108.15   Yes
# 4           42.30        1840.75    No
# 5           70.70         151.65   Yes
# 6           99.65          820.5   Yes
# 7           89.10         1949.4    No
# 8           29.75          301.9    No
# 9          104.80        3046.05   Yes
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Data Preparation

# %%
X = pd.get_dummies(data.drop(['Churn', 'Customer ID'], axis=1))
y = data['Churn'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %% [markdown]
# ## Build Model

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 177/177 [==============================] - 2s 6ms/step - loss: 0.5477 - accuracy: 0.7165
# Epoch 2/50
# 177/177 [==============================] - 1s 6ms/step - loss: 0.4940 - accuracy: 0.7654
# Epoch 3/50
# 177/177 [==============================] - 1s 5ms/step - loss: 0.4778 - accuracy: 0.7711: 1s
# Epoch 4/50
# 177/177 [==============================] - 1s 5ms/step - loss: 0.4888 - accuracy: 0.7707
# Epoch 5/50
# 177/177 [==============================] - 1s 5ms/step - loss: 0.4905 - accuracy: 0.7717
# Epoch 6/50
# 177/177 [==============================] - 1s 5ms/step - loss: 0.4594 - accuracy: 0.7911
# Epoch 7/50
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4663 - accuracy: 0.7790
# Epoch 8/50
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4729 - accuracy: 0.7824
# Epoch 9/50
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4649 - accuracy: 0.7824
# Epoch 10/50
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4618 - accuracy: 0.7865
# Epoch 11/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4787 - accuracy: 0.7667
# Epoch 12/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4606 - accuracy: 0.7839
# Epoch 13/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4560 - accuracy: 0.7826
# Epoch 14/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4553 - accuracy: 0.7902
# Epoch 15/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4633 - accuracy: 0.7793: 0s - loss: 0.4659 - accura
# Epoch 16/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4527 - accuracy: 0.7917
# Epoch 17/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4510 - accuracy: 0.7898
# Epoch 18/50
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4613 - accuracy: 0.7799
# Epoch 19/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4632 - accuracy: 0.7750
# Epoch 20/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4431 - accuracy: 0.7850
# Epoch 21/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4567 - accuracy: 0.7823
# Epoch 22/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4576 - accuracy: 0.7863
# Epoch 23/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4515 - accuracy: 0.7898
# Epoch 24/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4556 - accuracy: 0.7824
# Epoch 25/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4524 - accuracy: 0.7851
# Epoch 26/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4628 - accuracy: 0.7837
# Epoch 27/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4503 - accuracy: 0.7933
# Epoch 28/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4539 - accuracy: 0.7846
# Epoch 29/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4512 - accuracy: 0.7849
# Epoch 30/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4487 - accuracy: 0.7882
# Epoch 31/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4494 - accuracy: 0.7923
# Epoch 32/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4358 - accuracy: 0.8013
# Epoch 33/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4478 - accuracy: 0.7898
# Epoch 34/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4425 - accuracy: 0.7848
# Epoch 35/50
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4678 - accuracy: 0.7645
# Epoch 36/50
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4414 - accuracy: 0.7871
# Epoch 37/50
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4490 - accuracy: 0.7882
# Epoch 38/50
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4388 - accuracy: 0.7956
# Epoch 39/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4436 - accuracy: 0.7850
# Epoch 40/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4335 - accuracy: 0.7936
# Epoch 41/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4521 - accuracy: 0.7843
# Epoch 42/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4428 - accuracy: 0.7901
# Epoch 43/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4496 - accuracy: 0.7825
# Epoch 44/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4455 - accuracy: 0.7872
# Epoch 45/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4517 - accuracy: 0.7851
# Epoch 46/50
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4496 - accuracy: 0.7893
# Epoch 47/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4478 - accuracy: 0.7908
# Epoch 48/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4405 - accuracy: 0.7929
# Epoch 49/50
# 177/177 [==============================] - 0s 3ms/step - loss: 0.4456 - accuracy: 0.7821
# Epoch 50/50
# 177/177 [==============================] - 1s 3ms/step - loss: 0.4268 - accuracy: 0.8009

# %% [markdown]
# ## Evaluate Model

# %%
y_hat = model.predict(X_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.7885024840312278
