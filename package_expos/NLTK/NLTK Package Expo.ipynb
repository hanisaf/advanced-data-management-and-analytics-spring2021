# %%
#pip install --user -U nltk
# Out:
# Collecting nltkNote: you may need to restart the kernel to use updated packages.
#   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
# Requirement already satisfied, skipping upgrade: regex in c:\users\elise\anaconda3\lib\site-packages (from nltk) (2020.10.15)
# Requirement already satisfied, skipping upgrade: click in c:\users\elise\anaconda3\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied, skipping upgrade: joblib in c:\users\elise\anaconda3\lib\site-packages (from nltk) (0.17.0)
# Requirement already satisfied, skipping upgrade: tqdm in c:\users\elise\anaconda3\lib\site-packages (from nltk) (4.50.2)
# Installing collected packages: nltk
# Successfully installed nltk-3.6.2
#   WARNING: The script nltk.exe is installed in 'C:\Users\elise\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import nltk as nltk

# %%
poem = """Congratulations!
Today is your day.
You're off to Great Places!
You're off and away!

You have brains in your head.
You have feet in your shoes.
You can steer yourself
any direction you choose.
You're on your own. And you know what you know.
And YOU are the guy who'll decide where to go.

You'll look up and down streets. Look 'em over with care.
About some you will say, "I don't choose to go there."
With your head full of brains and your shoes full of feet,
you're too smart to go down any not-so-good street.

And you may not find any
you'll want to go down.
In that case, of course,
you'll head straight out of town.

It's opener there
in the wide open air.

Out there things can happen
and frequently do
to people as brainy
and footsy as you.

And then things start to happen,
don't worry. Don't stew.
Just go right along.
You'll start happening too.

OH!
THE PLACES YOU'LL GO!

You'll be on y our way up!
You'll be seeing great sights!
You'll join the high fliers
who soar to high heights.

You won't lag behind, because you'll have the speed.
You'll pass the whole gang and you'll soon take the lead.
Wherever you fly, you'll be best of the best.
Wherever you go, you will top all the rest.

Except when you don't.
Because, sometimes, you won't.

I'm sorry to say so
but, sadly, it's true
that Bang-ups
and Hang-ups
can happen to you.

You can get all hung up
in a prickle-ly perch.
And your gang will fly on.
You'll be left in a Lurch.

You'll come down from the Lurch
with an unpleasant bump.
And the chances are, then,
that you'll be in a Slump.

And when you're in a Slump,
you're not in for much fun.
Un-slumping yourself
is not easily done.

You will come to a place where the streets are not marked.
Some windows are lighted. But mostly they're darked.
A place you could sprain both your elbow and chin!
Do you dare to stay out? Do you dare to go in?
How much can you lose? How much can you win?

And IF you go in, should you turn left or right...
or right-and-three-quarters? Or, maybe, not quite?
Or go around back and sneak in from behind?
Simple it's not, I'm afraid you will find,
for a mind-maker-upper to make up his mind.

You can get so confused
that you'll start in to race
down long wiggled roads at a break-necking pace
and grind on for miles cross weirdish wild space,
headed, I fear, toward a most useless place.
The Waiting Place...

...for people just waiting.
Waiting for a train to go
or a bus to come, or a plane to go
or the mail to come, or the rain to go
or the phone to ring, or the snow to snow
or the waiting around for a Yes or No
or waiting for their hair to grow.
Everyone is just waiting.

Waiting for the fish to bite
or waiting for the wind to fly a kite
or waiting around for Friday night
or waiting, perhaps, for their Uncle Jake
or a pot to boil, or a Better Break
or a string of pearls, or a pair of pants
or a wig with curls, or Another Chance.
Everyone is just waiting.

NO!
That's not for you!

Somehow you'll escape
all that waiting and staying
You'll find the bright places
where Boom Bands are playing.

With banner flip-flapping,
once more you'll ride high!
Ready for anything under the sky.
Ready because you're that kind of a guy!

Oh, the places you'll go! There is fun to be done!
There are points to be scored. There are games to be won.
And the magical things you can do with that ball
will make you the winning-est winner of all.
Fame! You'll be as famous as famous can be,
with the whole wide world watching you win on TV.

Except when they don't
Because, sometimes they won't.

I'm afraid that some times
you'll play lonely games too.
Games you can't win
'cause you'll play against you.

All Alone!
Whether you like it or not,
Alone will be something
you'll be quite a lot.

And when you're alone, there's a very good chance
you'll meet things that scare you right out of your pants.
There are some, down the road between hither and yon,
that can scare you so much you won't want to go on.

But on you will go
though the weather be foul.
On you will go
though your enemies prowl.
On you will go
though the Hakken-Kraks howl.
Onward up many
a frightening creek,
though your arms may get sore
and your sneakers may leak.

On and on you will hike,
And I know you'll hike far
and face up to your problems
whatever they are.

You'll get mixed up, of course,
as you already know.
You'll get mixed up
with many strange birds as you go.
So be sure when you step.
Step with care and great tact
and remember that Life's
a Great Balancing Act.
Just never foget to be dexterous and deft.
And never mix up your right foot with your left.

And will you succeed?
Yes! You will, indeed!
(98 and 3/4 percent guaranteed.)

KID, YOU'LL MOVE MOUNTAINS!

So...
be your name Buxbaum or Bixby or Bray
or Mordecai Ali Van Allen O'Shea,
You're off the Great Places!
Today is your day!
Your mountain is waiting.
So...get on your way!"""

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\elise\AppData\Roaming\nltk_data...
# True

# %%
#Tokenize Function - Splits into list of words 
from nltk.tokenize import word_tokenize
words_list = word_tokenize(poem)
words_list
# Out:
# ['Congratulations',
#  '!',
#  'Today',
#  'is',
#  'your',
#  'day',
#  '.',
#  'You',
#  "'re",
#  'off',
#  'to',
#  'Great',
#  'Places',
#  '!',
#  'You',
#  "'re",
#  'off',
#  'and',
#  'away',
#  '!',
#  'You',
#  'have',
#  'brains',
#  'in',
#  'your',
#  'head',
#  '.',
#  'You',
#  'have',
#  'feet',
#  'in',
#  'your',
#  'shoes',
#  '.',
#  'You',
#  'can',
#  'steer',
#  'yourself',
#  'any',
#  'direction',
#  'you',
#  'choose',
#  '.',
#  'You',
#  "'re",
#  'on',
#  'your',
#  'own',
#  '.',
#  'And',
#  'you',
#  'know',
#  'what',
#  'you',
#  'know',
#  '.',
#  'And',
#  'YOU',
#  'are',
#  'the',
#  'guy',
#  'who',
#  "'ll",
#  'decide',
#  'where',
#  'to',
#  'go',
#  '.',
#  'You',
#  "'ll",
#  'look',
#  'up',
#  'and',
#  'down',
#  'streets',
#  '.',
#  'Look',
#  "'em",
#  'over',
#  'with',
#  'care',
#  '.',
#  'About',
#  'some',
#  'you',
#  'will',
#  'say',
#  ',',
#  '``',
#  'I',
#  'do',
#  "n't",
#  'choose',
#  'to',
#  'go',
#  'there',
#  '.',
#  "''",
#  'With',
#  'your',
#  'head',
#  'full',
#  'of',
#  'brains',
#  'and',
#  'your',
#  'shoes',
#  'full',
#  'of',
#  'feet',
#  ',',
#  'you',
#  "'re",
#  'too',
#  'smart',
#  'to',
#  'go',
#  'down',
#  'any',
#  'not-so-good',
#  'street',
#  '.',
#  'And',
#  'you',
#  'may',
#  'not',
#  'find',
#  'any',
#  'you',
#  "'ll",
#  'want',
#  'to',
#  'go',
#  'down',
#  '.',
#  'In',
#  'that',
#  'case',
#  ',',
#  'of',
#  'course',
#  ',',
#  'you',
#  "'ll",
#  'head',
#  'straight',
#  'out',
#  'of',
#  'town',
#  '.',
#  'It',
#  "'s",
#  'opener',
#  'there',
#  'in',
#  'the',
#  'wide',
#  'open',
#  'air',
#  '.',
#  'Out',
#  'there',
#  'things',
#  'can',
#  'happen',
#  'and',
#  'frequently',
#  'do',
#  'to',
#  'people',
#  'as',
#  'brainy',
#  'and',
#  'footsy',
#  'as',
#  'you',
#  '.',
#  'And',
#  'then',
#  'things',
#  'start',
#  'to',
#  'happen',
#  ',',
#  'do',
#  "n't",
#  'worry',
#  '.',
#  'Do',
#  "n't",
#  'stew',
#  '.',
#  'Just',
#  'go',
#  'right',
#  'along',
#  '.',
#  'You',
#  "'ll",
#  'start',
#  'happening',
#  'too',
#  '.',
#  'OH',
#  '!',
#  'THE',
#  'PLACES',
#  'YOU',
#  "'LL",
#  'GO',
#  '!',
#  'You',
#  "'ll",
#  'be',
#  'on',
#  'y',
#  'our',
#  'way',
#  'up',
#  '!',
#  'You',
#  "'ll",
#  'be',
#  'seeing',
#  'great',
#  'sights',
#  '!',
#  'You',
#  "'ll",
#  'join',
#  'the',
#  'high',
#  'fliers',
#  'who',
#  'soar',
#  'to',
#  'high',
#  'heights',
#  '.',
#  'You',
#  'wo',
#  "n't",
#  'lag',
#  'behind',
#  ',',
#  'because',
#  'you',
#  "'ll",
#  'have',
#  'the',
#  'speed',
#  '.',
#  'You',
#  "'ll",
#  'pass',
#  'the',
#  'whole',
#  'gang',
#  'and',
#  'you',
#  "'ll",
#  'soon',
#  'take',
#  'the',
#  'lead',
#  '.',
#  'Wherever',
#  'you',
#  'fly',
#  ',',
#  'you',
#  "'ll",
#  'be',
#  'best',
#  'of',
#  'the',
#  'best',
#  '.',
#  'Wherever',
#  'you',
#  'go',
#  ',',
#  'you',
#  'will',
#  'top',
#  'all',
#  'the',
#  'rest',
#  '.',
#  'Except',
#  'when',
#  'you',
#  'do',
#  "n't",
#  '.',
#  'Because',
#  ',',
#  'sometimes',
#  ',',
#  'you',
#  'wo',
#  "n't",
#  '.',
#  'I',
#  "'m",
#  'sorry',
#  'to',
#  'say',
#  'so',
#  'but',
#  ',',
#  'sadly',
#  ',',
#  'it',
#  "'s",
#  'true',
#  'that',
#  'Bang-ups',
#  'and',
#  'Hang-ups',
#  'can',
#  'happen',
#  'to',
#  'you',
#  '.',
#  'You',
#  'can',
#  'get',
#  'all',
#  'hung',
#  'up',
#  'in',
#  'a',
#  'prickle-ly',
#  'perch',
#  '.',
#  'And',
#  'your',
#  'gang',
#  'will',
#  'fly',
#  'on',
#  '.',
#  'You',
#  "'ll",
#  'be',
#  'left',
#  'in',
#  'a',
#  'Lurch',
#  '.',
#  'You',
#  "'ll",
#  'come',
#  'down',
#  'from',
#  'the',
#  'Lurch',
#  'with',
#  'an',
#  'unpleasant',
#  'bump',
#  '.',
#  'And',
#  'the',
#  'chances',
#  'are',
#  ',',
#  'then',
#  ',',
#  'that',
#  'you',
#  "'ll",
#  'be',
#  'in',
#  'a',
#  'Slump',
#  '.',
#  'And',
#  'when',
#  'you',
#  "'re",
#  'in',
#  'a',
#  'Slump',
#  ',',
#  'you',
#  "'re",
#  'not',
#  'in',
#  'for',
#  'much',
#  'fun',
#  '.',
#  'Un-slumping',
#  'yourself',
#  'is',
#  'not',
#  'easily',
#  'done',
#  '.',
#  'You',
#  'will',
#  'come',
#  'to',
#  'a',
#  'place',
#  'where',
#  'the',
#  'streets',
#  'are',
#  'not',
#  'marked',
#  '.',
#  'Some',
#  'windows',
#  'are',
#  'lighted',
#  '.',
#  'But',
#  'mostly',
#  'they',
#  "'re",
#  'darked',
#  '.',
#  'A',
#  'place',
#  'you',
#  'could',
#  'sprain',
#  'both',
#  'your',
#  'elbow',
#  'and',
#  'chin',
#  '!',
#  'Do',
#  'you',
#  'dare',
#  'to',
#  'stay',
#  'out',
#  '?',
#  'Do',
#  'you',
#  'dare',
#  'to',
#  'go',
#  'in',
#  '?',
#  'How',
#  'much',
#  'can',
#  'you',
#  'lose',
#  '?',
#  'How',
#  'much',
#  'can',
#  'you',
#  'win',
#  '?',
#  'And',
#  'IF',
#  'you',
#  'go',
#  'in',
#  ',',
#  'should',
#  'you',
#  'turn',
#  'left',
#  'or',
#  'right',
#  '...',
#  'or',
#  'right-and-three-quarters',
#  '?',
#  'Or',
#  ',',
#  'maybe',
#  ',',
#  'not',
#  'quite',
#  '?',
#  'Or',
#  'go',
#  'around',
#  'back',
#  'and',
#  'sneak',
#  'in',
#  'from',
#  'behind',
#  '?',
#  'Simple',
#  'it',
#  "'s",
#  'not',
#  ',',
#  'I',
#  "'m",
#  'afraid',
#  'you',
#  'will',
#  'find',
#  ',',
#  'for',
#  'a',
#  'mind-maker-upper',
#  'to',
#  'make',
#  'up',
#  'his',
#  'mind',
#  '.',
#  'You',
#  'can',
#  'get',
#  'so',
#  'confused',
#  'that',
#  'you',
#  "'ll",
#  'start',
#  'in',
#  'to',
#  'race',
#  'down',
#  'long',
#  'wiggled',
#  'roads',
#  'at',
#  'a',
#  'break-necking',
#  'pace',
#  'and',
#  'grind',
#  'on',
#  'for',
#  'miles',
#  'cross',
#  'weirdish',
#  'wild',
#  'space',
#  ',',
#  'headed',
#  ',',
#  'I',
#  'fear',
#  ',',
#  'toward',
#  'a',
#  'most',
#  'useless',
#  'place',
#  '.',
#  'The',
#  'Waiting',
#  'Place',
#  '...',
#  '...',
#  'for',
#  'people',
#  'just',
#  'waiting',
#  '.',
#  'Waiting',
#  'for',
#  'a',
#  'train',
#  'to',
#  'go',
#  'or',
#  'a',
#  'bus',
#  'to',
#  'come',
#  ',',
#  'or',
#  'a',
#  'plane',
#  'to',
#  'go',
#  'or',
#  'the',
#  'mail',
#  'to',
#  'come',
#  ',',
#  'or',
#  'the',
#  'rain',
#  'to',
#  'go',
#  'or',
#  'the',
#  'phone',
#  'to',
#  'ring',
#  ',',
#  'or',
#  'the',
#  'snow',
#  'to',
#  'snow',
#  'or',
#  'the',
#  'waiting',
#  'around',
#  'for',
#  'a',
#  'Yes',
#  'or',
#  'No',
#  'or',
#  'waiting',
#  'for',
#  'their',
#  'hair',
#  'to',
#  'grow',
#  '.',
#  'Everyone',
#  'is',
#  'just',
#  'waiting',
#  '.',
#  'Waiting',
#  'for',
#  'the',
#  'fish',
#  'to',
#  'bite',
#  'or',
#  'waiting',
#  'for',
#  'the',
#  'wind',
#  'to',
#  'fly',
#  'a',
#  'kite',
#  'or',
#  'waiting',
#  'around',
#  'for',
#  'Friday',
#  'night',
#  'or',
#  'waiting',
#  ',',
#  'perhaps',
#  ',',
#  'for',
#  'their',
#  'Uncle',
#  'Jake',
#  'or',
#  'a',
#  'pot',
#  'to',
#  'boil',
#  ',',
#  'or',
#  'a',
#  'Better',
#  'Break',
#  'or',
#  'a',
#  'string',
#  'of',
#  'pearls',
#  ',',
#  'or',
#  'a',
#  'pair',
#  'of',
#  'pants',
#  'or',
#  'a',
#  'wig',
#  'with',
#  'curls',
#  ',',
#  'or',
#  'Another',
#  'Chance',
#  '.',
#  'Everyone',
#  'is',
#  'just',
#  'waiting',
#  '.',
#  'NO',
#  '!',
#  'That',
#  "'s",
#  'not',
#  'for',
#  'you',
#  '!',
#  'Somehow',
#  'you',
#  "'ll",
#  'escape',
#  'all',
#  'that',
#  'waiting',
#  'and',
#  'staying',
#  'You',
#  "'ll",
#  'find',
#  'the',
#  'bright',
#  'places',
#  'where',
#  'Boom',
#  'Bands',
#  'are',
#  'playing',
#  '.',
#  'With',
#  'banner',
#  'flip-flapping',
#  ',',
#  'once',
#  'more',
#  'you',
#  "'ll",
#  'ride',
#  'high',
#  '!',
#  'Ready',
#  'for',
#  'anything',
#  'under',
#  'the',
#  'sky',
#  '.',
#  'Ready',
#  'because',
#  'you',
#  "'re",
#  'that',
#  'kind',
#  'of',
#  'a',
#  'guy',
#  '!',
#  'Oh',
#  ',',
#  'the',
#  'places',
#  'you',
#  "'ll",
#  'go',
#  '!',
#  'There',
#  'is',
#  'fun',
#  'to',
#  'be',
#  'done',
#  '!',
#  'There',
#  'are',
#  'points',
#  'to',
#  'be',
#  'scored',
#  '.',
#  'There',
#  'are',
#  'games',
#  'to',
#  'be',
#  'won',
#  '.',
#  'And',
#  'the',
#  'magical',
#  'things',
#  'you',
#  'can',
#  'do',
#  'with',
#  'that',
#  'ball',
#  'will',
#  'make',
#  'you',
#  'the',
#  'winning-est',
#  'winner',
#  'of',
#  'all',
#  '.',
#  'Fame',
#  '!',
#  'You',
#  "'ll",
#  'be',
#  'as',
#  'famous',
#  'as',
#  'famous',
#  'can',
#  'be',
#  ',',
#  'with',
#  'the',
#  'whole',
#  'wide',
#  'world',
#  'watching',
#  'you',
#  'win',
#  'on',
#  'TV',
#  '.',
#  'Except',
#  'when',
#  'they',
#  "don't",
#  'Because',
#  ',',
#  'sometimes',
#  'they',
#  'wo',
#  "n't",
#  '.',
#  'I',
#  "'m",
#  'afraid',
#  'that',
#  'some',
#  'times',
#  'you',
#  "'ll",
#  'play',
#  'lonely',
#  'games',
#  'too',
#  '.',
#  'Games',
#  'you',
#  'ca',
#  "n't",
#  'win',
#  "'cause",
#  'you',
#  "'ll",
#  'play',
#  'against',
#  'you',
#  '.',
#  'All',
#  'Alone',
#  '!',
#  'Whether',
#  'you',
#  'like',
#  'it',
#  'or',
#  'not',
#  ',',
#  'Alone',
#  'will',
#  'be',
#  'something',
#  'you',
#  "'ll",
#  'be',
#  'quite',
#  'a',
#  'lot',
#  '.',
#  'And',
#  'when',
#  'you',
#  "'re",
#  'alone',
#  ',',
#  'there',
#  "'s",
#  'a',
#  'very',
#  'good',
#  'chance',
#  'you',
#  "'ll",
#  'meet',
#  'things',
#  'that',
#  'scare',
#  'you',
#  'right',
#  'out',
#  'of',
#  'your',
#  'pants',
#  '.',
#  'There',
#  'are',
#  'some',
#  ',',
#  'down',
#  'the',
#  'road',
#  'between',
#  'hither',
#  'and',
#  'yon',
#  ',',
#  'that',
#  'can',
#  'scare',
#  'you',
#  'so',
#  'much',
#  'you',
#  'wo',
#  "n't",
#  'want',
#  'to',
#  'go',
#  'on',
#  '.',
#  'But',
#  'on',
#  'you',
#  'will',
#  'go',
#  'though',
#  'the',
#  'weather',
#  'be',
#  'foul',
#  '.',
#  'On',
#  'you',
#  'will',
#  'go',
#  'though',
#  'your',
#  'enemies',
#  'prowl',
#  '.',
#  'On',
#  'you',
#  'will',
#  'go',
#  'though',
#  'the',
#  'Hakken-Kraks',
#  'howl',
#  '.',
#  'Onward',
#  'up',
#  'many',
#  'a',
#  'frightening',
#  'creek',
#  ',',
#  'though',
#  'your',
#  'arms',
#  'may',
#  'get',
#  'sore',
#  'and',
#  'your',
#  'sneakers',
#  'may',
#  'leak',
#  '.',
#  'On',
#  'and',
#  'on',
#  'you',
#  'will',
#  'hike',
#  ',',
#  'And',
#  'I',
#  'know',
#  'you',
#  "'ll",
#  'hike',
#  'far',
#  'and',
#  'face',
#  'up',
#  'to',
#  'your',
#  'problems',
#  'whatever',
#  'they',
#  ...]

# %%
#Sentiment Analysis
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
sia.polarity_scores(poem)
# Out:
# {'neg': 0.07, 'neu': 0.79, 'pos': 0.14, 'compound': 0.9971}

# %%
#Part of Speech Tagging 
nltk.pos_tag(words_list)
# Out:
# [('Congratulations', 'NNS'),
#  ('!', '.'),
#  ('Today', 'NN'),
#  ('is', 'VBZ'),
#  ('your', 'PRP$'),
#  ('day', 'NN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ("'re", 'VBP'),
#  ('off', 'IN'),
#  ('to', 'TO'),
#  ('Great', 'NNP'),
#  ('Places', 'NNPS'),
#  ('!', '.'),
#  ('You', 'PRP'),
#  ("'re", 'VBP'),
#  ('off', 'IN'),
#  ('and', 'CC'),
#  ('away', 'RB'),
#  ('!', '.'),
#  ('You', 'PRP'),
#  ('have', 'VBP'),
#  ('brains', 'NNS'),
#  ('in', 'IN'),
#  ('your', 'PRP$'),
#  ('head', 'NN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('have', 'VBP'),
#  ('feet', 'NNS'),
#  ('in', 'IN'),
#  ('your', 'PRP$'),
#  ('shoes', 'NNS'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('can', 'MD'),
#  ('steer', 'VB'),
#  ('yourself', 'PRP'),
#  ('any', 'DT'),
#  ('direction', 'NN'),
#  ('you', 'PRP'),
#  ('choose', 'VBP'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ("'re", 'VBP'),
#  ('on', 'IN'),
#  ('your', 'PRP$'),
#  ('own', 'JJ'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('you', 'PRP'),
#  ('know', 'VBP'),
#  ('what', 'WP'),
#  ('you', 'PRP'),
#  ('know', 'VBP'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('YOU', 'PRP'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('guy', 'NN'),
#  ('who', 'WP'),
#  ("'ll", 'MD'),
#  ('decide', 'VB'),
#  ('where', 'WRB'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('look', 'VB'),
#  ('up', 'RP'),
#  ('and', 'CC'),
#  ('down', 'RB'),
#  ('streets', 'NNS'),
#  ('.', '.'),
#  ('Look', 'NNP'),
#  ("'em", 'VBZ'),
#  ('over', 'IN'),
#  ('with', 'IN'),
#  ('care', 'NN'),
#  ('.', '.'),
#  ('About', 'IN'),
#  ('some', 'DT'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('say', 'VB'),
#  (',', ','),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('choose', 'VB'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('there', 'RB'),
#  ('.', '.'),
#  ("''", "''"),
#  ('With', 'IN'),
#  ('your', 'PRP$'),
#  ('head', 'NN'),
#  ('full', 'JJ'),
#  ('of', 'IN'),
#  ('brains', 'NNS'),
#  ('and', 'CC'),
#  ('your', 'PRP$'),
#  ('shoes', 'NNS'),
#  ('full', 'JJ'),
#  ('of', 'IN'),
#  ('feet', 'NNS'),
#  (',', ','),
#  ('you', 'PRP'),
#  ("'re", 'VBP'),
#  ('too', 'RB'),
#  ('smart', 'JJ'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('down', 'RP'),
#  ('any', 'DT'),
#  ('not-so-good', 'JJ'),
#  ('street', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('you', 'PRP'),
#  ('may', 'MD'),
#  ('not', 'RB'),
#  ('find', 'VB'),
#  ('any', 'DT'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('want', 'VB'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('down', 'RP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('that', 'DT'),
#  ('case', 'NN'),
#  (',', ','),
#  ('of', 'IN'),
#  ('course', 'NN'),
#  (',', ','),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('head', 'VB'),
#  ('straight', 'VBD'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('town', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('opener', 'JJR'),
#  ('there', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('wide', 'JJ'),
#  ('open', 'JJ'),
#  ('air', 'NN'),
#  ('.', '.'),
#  ('Out', 'IN'),
#  ('there', 'RB'),
#  ('things', 'NNS'),
#  ('can', 'MD'),
#  ('happen', 'VB'),
#  ('and', 'CC'),
#  ('frequently', 'RB'),
#  ('do', 'VBP'),
#  ('to', 'TO'),
#  ('people', 'NNS'),
#  ('as', 'IN'),
#  ('brainy', 'NN'),
#  ('and', 'CC'),
#  ('footsy', 'NN'),
#  ('as', 'IN'),
#  ('you', 'PRP'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('then', 'RB'),
#  ('things', 'NNS'),
#  ('start', 'VBP'),
#  ('to', 'TO'),
#  ('happen', 'VB'),
#  (',', ','),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('worry', 'VB'),
#  ('.', '.'),
#  ('Do', 'VBP'),
#  ("n't", 'RB'),
#  ('stew', 'VB'),
#  ('.', '.'),
#  ('Just', 'NNP'),
#  ('go', 'VB'),
#  ('right', 'RB'),
#  ('along', 'RB'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('start', 'VB'),
#  ('happening', 'VBG'),
#  ('too', 'RB'),
#  ('.', '.'),
#  ('OH', 'UH'),
#  ('!', '.'),
#  ('THE', 'DT'),
#  ('PLACES', 'NNP'),
#  ('YOU', 'NNP'),
#  ("'LL", 'POS'),
#  ('GO', 'NNP'),
#  ('!', '.'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('be', 'VB'),
#  ('on', 'IN'),
#  ('y', 'PRP'),
#  ('our', 'PRP$'),
#  ('way', 'NN'),
#  ('up', 'RP'),
#  ('!', '.'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('be', 'VB'),
#  ('seeing', 'VBG'),
#  ('great', 'JJ'),
#  ('sights', 'NNS'),
#  ('!', '.'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('join', 'VB'),
#  ('the', 'DT'),
#  ('high', 'JJ'),
#  ('fliers', 'NNS'),
#  ('who', 'WP'),
#  ('soar', 'VBP'),
#  ('to', 'TO'),
#  ('high', 'JJ'),
#  ('heights', 'NNS'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('lag', 'VB'),
#  ('behind', 'RB'),
#  (',', ','),
#  ('because', 'IN'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('have', 'VB'),
#  ('the', 'DT'),
#  ('speed', 'NN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('pass', 'VB'),
#  ('the', 'DT'),
#  ('whole', 'JJ'),
#  ('gang', 'NN'),
#  ('and', 'CC'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('soon', 'RB'),
#  ('take', 'VB'),
#  ('the', 'DT'),
#  ('lead', 'NN'),
#  ('.', '.'),
#  ('Wherever', 'IN'),
#  ('you', 'PRP'),
#  ('fly', 'VBP'),
#  (',', ','),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('be', 'VB'),
#  ('best', 'JJS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('.', '.'),
#  ('Wherever', 'VB'),
#  ('you', 'PRP'),
#  ('go', 'VBP'),
#  (',', ','),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('top', 'VB'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('rest', 'NN'),
#  ('.', '.'),
#  ('Except', 'IN'),
#  ('when', 'WRB'),
#  ('you', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('.', '.'),
#  ('Because', 'IN'),
#  (',', ','),
#  ('sometimes', 'RB'),
#  (',', ','),
#  ('you', 'PRP'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('sorry', 'JJ'),
#  ('to', 'TO'),
#  ('say', 'VB'),
#  ('so', 'RB'),
#  ('but', 'CC'),
#  (',', ','),
#  ('sadly', 'RB'),
#  (',', ','),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('true', 'JJ'),
#  ('that', 'IN'),
#  ('Bang-ups', 'NNP'),
#  ('and', 'CC'),
#  ('Hang-ups', 'NNP'),
#  ('can', 'MD'),
#  ('happen', 'VB'),
#  ('to', 'TO'),
#  ('you', 'PRP'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('can', 'MD'),
#  ('get', 'VB'),
#  ('all', 'DT'),
#  ('hung', 'NN'),
#  ('up', 'RP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('prickle-ly', 'JJ'),
#  ('perch', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('your', 'PRP$'),
#  ('gang', 'NN'),
#  ('will', 'MD'),
#  ('fly', 'VB'),
#  ('on', 'IN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('be', 'VB'),
#  ('left', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('Lurch', 'NNP'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('come', 'VB'),
#  ('down', 'RP'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('Lurch', 'NNP'),
#  ('with', 'IN'),
#  ('an', 'DT'),
#  ('unpleasant', 'JJ'),
#  ('bump', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('the', 'DT'),
#  ('chances', 'NNS'),
#  ('are', 'VBP'),
#  (',', ','),
#  ('then', 'RB'),
#  (',', ','),
#  ('that', 'IN'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('be', 'VB'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('Slump', 'NNP'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('when', 'WRB'),
#  ('you', 'PRP'),
#  ("'re", 'VBP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('Slump', 'NNP'),
#  (',', ','),
#  ('you', 'PRP'),
#  ("'re", 'VBP'),
#  ('not', 'RB'),
#  ('in', 'IN'),
#  ('for', 'IN'),
#  ('much', 'JJ'),
#  ('fun', 'NN'),
#  ('.', '.'),
#  ('Un-slumping', 'JJ'),
#  ('yourself', 'PRP'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('easily', 'RB'),
#  ('done', 'VBN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('will', 'MD'),
#  ('come', 'VB'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('place', 'NN'),
#  ('where', 'WRB'),
#  ('the', 'DT'),
#  ('streets', 'NNS'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('marked', 'VBN'),
#  ('.', '.'),
#  ('Some', 'DT'),
#  ('windows', 'NNS'),
#  ('are', 'VBP'),
#  ('lighted', 'VBN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('mostly', 'RB'),
#  ('they', 'PRP'),
#  ("'re", 'VBP'),
#  ('darked', 'VBN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('place', 'NN'),
#  ('you', 'PRP'),
#  ('could', 'MD'),
#  ('sprain', 'VB'),
#  ('both', 'DT'),
#  ('your', 'PRP$'),
#  ('elbow', 'NN'),
#  ('and', 'CC'),
#  ('chin', 'NN'),
#  ('!', '.'),
#  ('Do', 'NNP'),
#  ('you', 'PRP'),
#  ('dare', 'VB'),
#  ('to', 'TO'),
#  ('stay', 'VB'),
#  ('out', 'RP'),
#  ('?', '.'),
#  ('Do', 'VB'),
#  ('you', 'PRP'),
#  ('dare', 'VB'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('in', 'IN'),
#  ('?', '.'),
#  ('How', 'WRB'),
#  ('much', 'JJ'),
#  ('can', 'MD'),
#  ('you', 'PRP'),
#  ('lose', 'VB'),
#  ('?', '.'),
#  ('How', 'WRB'),
#  ('much', 'JJ'),
#  ('can', 'MD'),
#  ('you', 'PRP'),
#  ('win', 'VB'),
#  ('?', '.'),
#  ('And', 'CC'),
#  ('IF', 'NNP'),
#  ('you', 'PRP'),
#  ('go', 'VBP'),
#  ('in', 'IN'),
#  (',', ','),
#  ('should', 'MD'),
#  ('you', 'PRP'),
#  ('turn', 'VB'),
#  ('left', 'VBN'),
#  ('or', 'CC'),
#  ('right', 'JJ'),
#  ('...', ':'),
#  ('or', 'CC'),
#  ('right-and-three-quarters', 'NNS'),
#  ('?', '.'),
#  ('Or', 'CC'),
#  (',', ','),
#  ('maybe', 'RB'),
#  (',', ','),
#  ('not', 'RB'),
#  ('quite', 'RB'),
#  ('?', '.'),
#  ('Or', 'CC'),
#  ('go', 'VB'),
#  ('around', 'RP'),
#  ('back', 'RB'),
#  ('and', 'CC'),
#  ('sneak', 'NN'),
#  ('in', 'IN'),
#  ('from', 'IN'),
#  ('behind', 'IN'),
#  ('?', '.'),
#  ('Simple', 'NNP'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('not', 'RB'),
#  (',', ','),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('afraid', 'JJ'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('find', 'VB'),
#  (',', ','),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('mind-maker-upper', 'JJ'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('up', 'RP'),
#  ('his', 'PRP$'),
#  ('mind', 'NN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('can', 'MD'),
#  ('get', 'VB'),
#  ('so', 'RB'),
#  ('confused', 'JJ'),
#  ('that', 'IN'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('start', 'VB'),
#  ('in', 'IN'),
#  ('to', 'TO'),
#  ('race', 'NN'),
#  ('down', 'RP'),
#  ('long', 'RB'),
#  ('wiggled', 'JJ'),
#  ('roads', 'NNS'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('break-necking', 'JJ'),
#  ('pace', 'NN'),
#  ('and', 'CC'),
#  ('grind', 'NN'),
#  ('on', 'IN'),
#  ('for', 'IN'),
#  ('miles', 'NNS'),
#  ('cross', 'RB'),
#  ('weirdish', 'JJ'),
#  ('wild', 'JJ'),
#  ('space', 'NN'),
#  (',', ','),
#  ('headed', 'VBN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('fear', 'VBP'),
#  (',', ','),
#  ('toward', 'IN'),
#  ('a', 'DT'),
#  ('most', 'RBS'),
#  ('useless', 'JJ'),
#  ('place', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Waiting', 'VBG'),
#  ('Place', 'NN'),
#  ('...', ':'),
#  ('...', ':'),
#  ('for', 'IN'),
#  ('people', 'NNS'),
#  ('just', 'RB'),
#  ('waiting', 'VBG'),
#  ('.', '.'),
#  ('Waiting', 'VBG'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('train', 'NN'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('or', 'CC'),
#  ('a', 'DT'),
#  ('bus', 'NN'),
#  ('to', 'TO'),
#  ('come', 'VB'),
#  (',', ','),
#  ('or', 'CC'),
#  ('a', 'DT'),
#  ('plane', 'NN'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('mail', 'NN'),
#  ('to', 'TO'),
#  ('come', 'VB'),
#  (',', ','),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('rain', 'NN'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('phone', 'NN'),
#  ('to', 'TO'),
#  ('ring', 'NN'),
#  (',', ','),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('snow', 'NN'),
#  ('to', 'TO'),
#  ('snow', 'VB'),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('waiting', 'VBG'),
#  ('around', 'RP'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('Yes', 'NNP'),
#  ('or', 'CC'),
#  ('No', 'NNP'),
#  ('or', 'CC'),
#  ('waiting', 'VBG'),
#  ('for', 'IN'),
#  ('their', 'PRP$'),
#  ('hair', 'NN'),
#  ('to', 'TO'),
#  ('grow', 'VB'),
#  ('.', '.'),
#  ('Everyone', 'NNP'),
#  ('is', 'VBZ'),
#  ('just', 'RB'),
#  ('waiting', 'VBG'),
#  ('.', '.'),
#  ('Waiting', 'VBG'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('fish', 'NN'),
#  ('to', 'TO'),
#  ('bite', 'VB'),
#  ('or', 'CC'),
#  ('waiting', 'VBG'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('wind', 'NN'),
#  ('to', 'TO'),
#  ('fly', 'VB'),
#  ('a', 'DT'),
#  ('kite', 'NN'),
#  ('or', 'CC'),
#  ('waiting', 'VBG'),
#  ('around', 'IN'),
#  ('for', 'IN'),
#  ('Friday', 'NNP'),
#  ('night', 'NN'),
#  ('or', 'CC'),
#  ('waiting', 'NN'),
#  (',', ','),
#  ('perhaps', 'RB'),
#  (',', ','),
#  ('for', 'IN'),
#  ('their', 'PRP$'),
#  ('Uncle', 'NNP'),
#  ('Jake', 'NNP'),
#  ('or', 'CC'),
#  ('a', 'DT'),
#  ('pot', 'NN'),
#  ('to', 'TO'),
#  ('boil', 'VB'),
#  (',', ','),
#  ('or', 'CC'),
#  ('a', 'DT'),
#  ('Better', 'JJR'),
#  ('Break', 'NNP'),
#  ('or', 'CC'),
#  ('a', 'DT'),
#  ('string', 'NN'),
#  ('of', 'IN'),
#  ('pearls', 'NN'),
#  (',', ','),
#  ('or', 'CC'),
#  ('a', 'DT'),
#  ('pair', 'NN'),
#  ('of', 'IN'),
#  ('pants', 'NNS'),
#  ('or', 'CC'),
#  ('a', 'DT'),
#  ('wig', 'NN'),
#  ('with', 'IN'),
#  ('curls', 'NNS'),
#  (',', ','),
#  ('or', 'CC'),
#  ('Another', 'DT'),
#  ('Chance', 'NN'),
#  ('.', '.'),
#  ('Everyone', 'NNP'),
#  ('is', 'VBZ'),
#  ('just', 'RB'),
#  ('waiting', 'VBG'),
#  ('.', '.'),
#  ('NO', 'UH'),
#  ('!', '.'),
#  ('That', 'DT'),
#  ("'s", 'VBZ'),
#  ('not', 'RB'),
#  ('for', 'IN'),
#  ('you', 'PRP'),
#  ('!', '.'),
#  ('Somehow', 'RB'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('escape', 'VB'),
#  ('all', 'DT'),
#  ('that', 'IN'),
#  ('waiting', 'VBG'),
#  ('and', 'CC'),
#  ('staying', 'VBG'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('find', 'VB'),
#  ('the', 'DT'),
#  ('bright', 'JJ'),
#  ('places', 'NNS'),
#  ('where', 'WRB'),
#  ('Boom', 'NNP'),
#  ('Bands', 'NNP'),
#  ('are', 'VBP'),
#  ('playing', 'VBG'),
#  ('.', '.'),
#  ('With', 'IN'),
#  ('banner', 'JJ'),
#  ('flip-flapping', 'JJ'),
#  (',', ','),
#  ('once', 'RB'),
#  ('more', 'JJR'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('ride', 'VB'),
#  ('high', 'JJ'),
#  ('!', '.'),
#  ('Ready', 'JJ'),
#  ('for', 'IN'),
#  ('anything', 'NN'),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('sky', 'NN'),
#  ('.', '.'),
#  ('Ready', 'JJ'),
#  ('because', 'IN'),
#  ('you', 'PRP'),
#  ("'re", 'VBP'),
#  ('that', 'IN'),
#  ('kind', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('guy', 'NN'),
#  ('!', '.'),
#  ('Oh', 'UH'),
#  (',', ','),
#  ('the', 'DT'),
#  ('places', 'NNS'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('go', 'VB'),
#  ('!', '.'),
#  ('There', 'EX'),
#  ('is', 'VBZ'),
#  ('fun', 'NN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('done', 'VBN'),
#  ('!', '.'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('points', 'NNS'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('scored', 'VBN'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('games', 'NNS'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('won', 'VBN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('the', 'DT'),
#  ('magical', 'JJ'),
#  ('things', 'NNS'),
#  ('you', 'PRP'),
#  ('can', 'MD'),
#  ('do', 'VB'),
#  ('with', 'IN'),
#  ('that', 'DT'),
#  ('ball', 'NN'),
#  ('will', 'MD'),
#  ('make', 'VB'),
#  ('you', 'PRP'),
#  ('the', 'DT'),
#  ('winning-est', 'JJ'),
#  ('winner', 'NN'),
#  ('of', 'IN'),
#  ('all', 'DT'),
#  ('.', '.'),
#  ('Fame', 'NN'),
#  ('!', '.'),
#  ('You', 'PRP'),
#  ("'ll", 'MD'),
#  ('be', 'VB'),
#  ('as', 'RB'),
#  ('famous', 'JJ'),
#  ('as', 'IN'),
#  ('famous', 'JJ'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  (',', ','),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('whole', 'JJ'),
#  ('wide', 'JJ'),
#  ('world', 'NN'),
#  ('watching', 'VBG'),
#  ('you', 'PRP'),
#  ('win', 'VBP'),
#  ('on', 'IN'),
#  ('TV', 'NN'),
#  ('.', '.'),
#  ('Except', 'IN'),
#  ('when', 'WRB'),
#  ('they', 'PRP'),
#  ("don't", 'VBP'),
#  ('Because', 'IN'),
#  (',', ','),
#  ('sometimes', 'RB'),
#  ('they', 'PRP'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('afraid', 'JJ'),
#  ('that', 'IN'),
#  ('some', 'DT'),
#  ('times', 'NNS'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('play', 'VB'),
#  ('lonely', 'RB'),
#  ('games', 'NNS'),
#  ('too', 'RB'),
#  ('.', '.'),
#  ('Games', 'NNPS'),
#  ('you', 'PRP'),
#  ('ca', 'MD'),
#  ("n't", 'RB'),
#  ('win', 'VB'),
#  ("'cause", 'IN'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('play', 'VB'),
#  ('against', 'IN'),
#  ('you', 'PRP'),
#  ('.', '.'),
#  ('All', 'DT'),
#  ('Alone', 'RB'),
#  ('!', '.'),
#  ('Whether', 'IN'),
#  ('you', 'PRP'),
#  ('like', 'IN'),
#  ('it', 'PRP'),
#  ('or', 'CC'),
#  ('not', 'RB'),
#  (',', ','),
#  ('Alone', 'NNP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('something', 'NN'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('be', 'VB'),
#  ('quite', 'RB'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('when', 'WRB'),
#  ('you', 'PRP'),
#  ("'re", 'VBP'),
#  ('alone', 'RB'),
#  (',', ','),
#  ('there', 'EX'),
#  ("'s", 'VBZ'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('good', 'JJ'),
#  ('chance', 'NN'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('meet', 'VB'),
#  ('things', 'NNS'),
#  ('that', 'WDT'),
#  ('scare', 'VBP'),
#  ('you', 'PRP'),
#  ('right', 'VBP'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('your', 'PRP$'),
#  ('pants', 'NNS'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('some', 'DT'),
#  (',', ','),
#  ('down', 'IN'),
#  ('the', 'DT'),
#  ('road', 'NN'),
#  ('between', 'IN'),
#  ('hither', 'NN'),
#  ('and', 'CC'),
#  ('yon', 'NN'),
#  (',', ','),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('scare', 'VB'),
#  ('you', 'PRP'),
#  ('so', 'RB'),
#  ('much', 'JJ'),
#  ('you', 'PRP'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('want', 'VB'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('on', 'IN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('on', 'IN'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('go', 'VB'),
#  ('though', 'IN'),
#  ('the', 'DT'),
#  ('weather', 'NN'),
#  ('be', 'VB'),
#  ('foul', 'VBN'),
#  ('.', '.'),
#  ('On', 'IN'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('go', 'VB'),
#  ('though', 'IN'),
#  ('your', 'PRP$'),
#  ('enemies', 'NNS'),
#  ('prowl', 'VBP'),
#  ('.', '.'),
#  ('On', 'IN'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('go', 'VB'),
#  ('though', 'IN'),
#  ('the', 'DT'),
#  ('Hakken-Kraks', 'NNP'),
#  ('howl', 'NN'),
#  ('.', '.'),
#  ('Onward', 'NNP'),
#  ('up', 'RB'),
#  ('many', 'JJ'),
#  ('a', 'DT'),
#  ('frightening', 'JJ'),
#  ('creek', 'NN'),
#  (',', ','),
#  ('though', 'IN'),
#  ('your', 'PRP$'),
#  ('arms', 'NNS'),
#  ('may', 'MD'),
#  ('get', 'VB'),
#  ('sore', 'JJR'),
#  ('and', 'CC'),
#  ('your', 'PRP$'),
#  ('sneakers', 'NNS'),
#  ('may', 'MD'),
#  ('leak', 'VB'),
#  ('.', '.'),
#  ('On', 'IN'),
#  ('and', 'CC'),
#  ('on', 'IN'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('hike', 'VB'),
#  (',', ','),
#  ('And', 'CC'),
#  ('I', 'PRP'),
#  ('know', 'VBP'),
#  ('you', 'PRP'),
#  ("'ll", 'MD'),
#  ('hike', 'VB'),
#  ('far', 'RB'),
#  ('and', 'CC'),
#  ('face', 'VB'),
#  ('up', 'RP'),
#  ('to', 'TO'),
#  ('your', 'PRP$'),
#  ('problems', 'NNS'),
#  ('whatever', 'IN'),
#  ('they', 'PRP'),
#  ...]

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
#Create the word frequency table
def _create_frequency_table(text_string) -> dict:

    stopWords = set(stopwords.words("english"))
    words = word_tokenize(text_string)
    ps = PorterStemmer()

    freqTable = dict()
    for word in words:
        word = ps.stem(word)
        if word in stopWords:
            continue
        if word in freqTable:
            freqTable[word] += 1
        else:
            freqTable[word] = 1

    return freqTable

# %%
#score a sentence by its words, adding the frequency of every non-stop word in a sentence
def _score_sentences(sentences, freqTable) -> dict:
    sentenceValue = dict()

    for sentence in sentences:
        word_count_in_sentence = (len(word_tokenize(sentence)))
        for wordValue in freqTable:
            if wordValue in sentence.lower():
                if sentence[:10] in sentenceValue:
                    sentenceValue[sentence[:10]] += freqTable[wordValue]
                else:
                    sentenceValue[sentence[:10]] = freqTable[wordValue]

        sentenceValue[sentence[:10]] = sentenceValue[sentence[:10]] // word_count_in_sentence

    return sentenceValue

# %%
#Find the threshold: average score of the sentences 
def _find_average_score(sentenceValue) -> int:
    sumValues = 0
    for entry in sentenceValue:
        sumValues += sentenceValue[entry]

    # Average value of a sentence from original text
    average = int(sumValues / len(sentenceValue))

    return average

# %%
#Generate the summary: Essentially, if the sentence score is more than the average score, keep the sentence
def _generate_summary(sentences, sentenceValue, threshold):
    sentence_count = 0
    summary = ''

    for sentence in sentences:
        if sentence[:10] in sentenceValue and sentenceValue[sentence[:10]] > (threshold):
            summary += " " + sentence
            sentence_count += 1

    return summary

# %%
# 1 Create the word frequency table
freq_table = _create_frequency_table(poem)
freq_table
# Out:
# {'congratul': 1,
#  '!': 22,
#  'today': 2,
#  'day': 2,
#  '.': 69,
#  "'re": 10,
#  'great': 5,
#  'place': 9,
#  'away': 1,
#  'brain': 2,
#  'head': 4,
#  'feet': 2,
#  'shoe': 2,
#  'steer': 1,
#  'ani': 3,
#  'direct': 1,
#  'choos': 2,
#  'know': 4,
#  'guy': 2,
#  "'ll": 30,
#  'decid': 1,
#  'go': 18,
#  'look': 2,
#  'street': 3,
#  "'em": 1,
#  'care': 2,
#  'say': 2,
#  ',': 46,
#  '``': 1,
#  'I': 6,
#  "n't": 9,
#  "''": 1,
#  'full': 2,
#  'smart': 1,
#  'not-so-good': 1,
#  'may': 3,
#  'find': 3,
#  'want': 2,
#  'In': 1,
#  'case': 1,
#  'cours': 2,
#  'straight': 1,
#  'town': 1,
#  'It': 1,
#  "'s": 5,
#  'open': 2,
#  'wide': 2,
#  'air': 1,
#  'thing': 4,
#  'happen': 4,
#  'frequent': 1,
#  'peopl': 2,
#  'braini': 1,
#  'footsi': 1,
#  'start': 3,
#  'worri': 1,
#  'Do': 3,
#  'stew': 1,
#  'right': 4,
#  'along': 1,
#  'OH': 1,
#  'GO': 1,
#  'way': 2,
#  'see': 1,
#  'sight': 1,
#  'join': 1,
#  'high': 3,
#  'flier': 1,
#  'soar': 1,
#  'height': 1,
#  'wo': 4,
#  'lag': 1,
#  'behind': 2,
#  'becaus': 4,
#  'speed': 1,
#  'pass': 1,
#  'whole': 2,
#  'gang': 2,
#  'soon': 1,
#  'take': 1,
#  'lead': 1,
#  'wherev': 2,
#  'fli': 3,
#  'best': 2,
#  'top': 1,
#  'rest': 1,
#  'except': 2,
#  'sometim': 2,
#  "'m": 3,
#  'sorri': 1,
#  'sadli': 1,
#  'true': 1,
#  'bang-up': 1,
#  'hang-up': 1,
#  'get': 6,
#  'hung': 1,
#  'prickle-li': 1,
#  'perch': 1,
#  'left': 3,
#  'lurch': 2,
#  'come': 4,
#  'unpleas': 1,
#  'bump': 1,
#  'chanc': 3,
#  'slump': 2,
#  'much': 4,
#  'fun': 2,
#  'un-slump': 1,
#  'easili': 1,
#  'done': 2,
#  'mark': 1,
#  'window': 1,
#  'light': 1,
#  'mostli': 1,
#  'dark': 1,
#  'A': 1,
#  'could': 1,
#  'sprain': 1,
#  'elbow': 1,
#  'chin': 1,
#  'dare': 2,
#  'stay': 2,
#  '?': 8,
#  'lose': 1,
#  'win': 3,
#  'IF': 1,
#  'turn': 1,
#  '...': 5,
#  'right-and-three-quart': 1,
#  'Or': 2,
#  'mayb': 1,
#  'quit': 2,
#  'around': 3,
#  'back': 1,
#  'sneak': 1,
#  'simpl': 1,
#  'afraid': 2,
#  'mind-maker-upp': 1,
#  'make': 2,
#  'hi': 1,
#  'mind': 1,
#  'confus': 1,
#  'race': 1,
#  'long': 1,
#  'wiggl': 1,
#  'road': 2,
#  'break-neck': 1,
#  'pace': 1,
#  'grind': 1,
#  'mile': 1,
#  'cross': 1,
#  'weirdish': 1,
#  'wild': 1,
#  'space': 1,
#  'fear': 1,
#  'toward': 1,
#  'useless': 1,
#  'wait': 13,
#  'train': 1,
#  'bu': 1,
#  'plane': 1,
#  'mail': 1,
#  'rain': 1,
#  'phone': 1,
#  'ring': 1,
#  'snow': 2,
#  'ye': 2,
#  'No': 1,
#  'hair': 1,
#  'grow': 1,
#  'everyon': 2,
#  'fish': 1,
#  'bite': 1,
#  'wind': 1,
#  'kite': 1,
#  'friday': 1,
#  'night': 1,
#  'perhap': 1,
#  'uncl': 1,
#  'jake': 1,
#  'pot': 1,
#  'boil': 1,
#  'better': 1,
#  'break': 1,
#  'string': 1,
#  'pearl': 1,
#  'pair': 1,
#  'pant': 2,
#  'wig': 1,
#  'curl': 1,
#  'anoth': 1,
#  'NO': 1,
#  'somehow': 1,
#  'escap': 1,
#  'bright': 1,
#  'boom': 1,
#  'band': 1,
#  'play': 3,
#  'banner': 1,
#  'flip-flap': 1,
#  'onc': 1,
#  'ride': 1,
#  'readi': 2,
#  'anyth': 1,
#  'sky': 1,
#  'kind': 1,
#  'Oh': 1,
#  'point': 1,
#  'score': 1,
#  'game': 3,
#  'magic': 1,
#  'ball': 1,
#  'winning-est': 1,
#  'winner': 1,
#  'fame': 1,
#  'famou': 2,
#  'world': 1,
#  'watch': 1,
#  'TV': 1,
#  'time': 1,
#  'lone': 1,
#  'ca': 1,
#  "'caus": 1,
#  'alon': 3,
#  'whether': 1,
#  'like': 1,
#  'someth': 1,
#  'lot': 1,
#  'veri': 1,
#  'good': 1,
#  'meet': 1,
#  'scare': 2,
#  'hither': 1,
#  'yon': 1,
#  'though': 4,
#  'weather': 1,
#  'foul': 1,
#  'On': 3,
#  'enemi': 1,
#  'prowl': 1,
#  'hakken-krak': 1,
#  'howl': 1,
#  'onward': 1,
#  'mani': 2,
#  'frighten': 1,
#  'creek': 1,
#  'arm': 1,
#  'sore': 1,
#  'sneaker': 1,
#  'leak': 1,
#  'hike': 2,
#  'far': 1,
#  'face': 1,
#  'problem': 1,
#  'whatev': 1,
#  'mix': 3,
#  'alreadi': 1,
#  'strang': 1,
#  'bird': 1,
#  'So': 3,
#  'sure': 1,
#  'step': 2,
#  'tact': 1,
#  'rememb': 1,
#  "life'": 1,
#  'balanc': 1,
#  'act': 1,
#  'never': 2,
#  'foget': 1,
#  'dexter': 1,
#  'deft': 1,
#  'foot': 1,
#  'succeed': 1,
#  'inde': 1,
#  '(': 1,
#  '98': 1,
#  '3/4': 1,
#  'percent': 1,
#  'guarante': 1,
#  ')': 1,
#  'kid': 1,
#  'move': 1,
#  'mountain': 2,
#  'name': 1,
#  'buxbaum': 1,
#  'bixbi': 1,
#  'bray': 1,
#  'mordecai': 1,
#  'ali': 1,
#  'van': 1,
#  'allen': 1,
#  "o'shea": 1}

# %%
# 2 Tokenize the sentences
sentences = sent_tokenize(poem)
sentences
# Out:
# ['Congratulations!',
#  'Today is your day.',
#  "You're off to Great Places!",
#  "You're off and away!",
#  'You have brains in your head.',
#  'You have feet in your shoes.',
#  'You can steer yourself\nany direction you choose.',
#  "You're on your own.",
#  'And you know what you know.',
#  "And YOU are the guy who'll decide where to go.",
#  "You'll look up and down streets.",
#  "Look 'em over with care.",
#  'About some you will say, "I don\'t choose to go there."',
#  "With your head full of brains and your shoes full of feet,\nyou're too smart to go down any not-so-good street.",
#  "And you may not find any\nyou'll want to go down.",
#  "In that case, of course,\nyou'll head straight out of town.",
#  "It's opener there\nin the wide open air.",
#  'Out there things can happen\nand frequently do\nto people as brainy\nand footsy as you.',
#  "And then things start to happen,\ndon't worry.",
#  "Don't stew.",
#  'Just go right along.',
#  "You'll start happening too.",
#  'OH!',
#  "THE PLACES YOU'LL GO!",
#  "You'll be on y our way up!",
#  "You'll be seeing great sights!",
#  "You'll join the high fliers\nwho soar to high heights.",
#  "You won't lag behind, because you'll have the speed.",
#  "You'll pass the whole gang and you'll soon take the lead.",
#  "Wherever you fly, you'll be best of the best.",
#  'Wherever you go, you will top all the rest.',
#  "Except when you don't.",
#  "Because, sometimes, you won't.",
#  "I'm sorry to say so\nbut, sadly, it's true\nthat Bang-ups\nand Hang-ups\ncan happen to you.",
#  'You can get all hung up\nin a prickle-ly perch.',
#  'And your gang will fly on.',
#  "You'll be left in a Lurch.",
#  "You'll come down from the Lurch\nwith an unpleasant bump.",
#  "And the chances are, then,\nthat you'll be in a Slump.",
#  "And when you're in a Slump,\nyou're not in for much fun.",
#  'Un-slumping yourself\nis not easily done.',
#  'You will come to a place where the streets are not marked.',
#  'Some windows are lighted.',
#  "But mostly they're darked.",
#  'A place you could sprain both your elbow and chin!',
#  'Do you dare to stay out?',
#  'Do you dare to go in?',
#  'How much can you lose?',
#  'How much can you win?',
#  'And IF you go in, should you turn left or right...\nor right-and-three-quarters?',
#  'Or, maybe, not quite?',
#  'Or go around back and sneak in from behind?',
#  "Simple it's not, I'm afraid you will find,\nfor a mind-maker-upper to make up his mind.",
#  "You can get so confused\nthat you'll start in to race\ndown long wiggled roads at a break-necking pace\nand grind on for miles cross weirdish wild space,\nheaded, I fear, toward a most useless place.",
#  'The Waiting Place...\n\n...for people just waiting.',
#  'Waiting for a train to go\nor a bus to come, or a plane to go\nor the mail to come, or the rain to go\nor the phone to ring, or the snow to snow\nor the waiting around for a Yes or No\nor waiting for their hair to grow.',
#  'Everyone is just waiting.',
#  'Waiting for the fish to bite\nor waiting for the wind to fly a kite\nor waiting around for Friday night\nor waiting, perhaps, for their Uncle Jake\nor a pot to boil, or a Better Break\nor a string of pearls, or a pair of pants\nor a wig with curls, or Another Chance.',
#  'Everyone is just waiting.',
#  'NO!',
#  "That's not for you!",
#  "Somehow you'll escape\nall that waiting and staying\nYou'll find the bright places\nwhere Boom Bands are playing.",
#  "With banner flip-flapping,\nonce more you'll ride high!",
#  'Ready for anything under the sky.',
#  "Ready because you're that kind of a guy!",
#  "Oh, the places you'll go!",
#  'There is fun to be done!',
#  'There are points to be scored.',
#  'There are games to be won.',
#  'And the magical things you can do with that ball\nwill make you the winning-est winner of all.',
#  'Fame!',
#  "You'll be as famous as famous can be,\nwith the whole wide world watching you win on TV.",
#  "Except when they don't\nBecause, sometimes they won't.",
#  "I'm afraid that some times\nyou'll play lonely games too.",
#  "Games you can't win\n'cause you'll play against you.",
#  'All Alone!',
#  "Whether you like it or not,\nAlone will be something\nyou'll be quite a lot.",
#  "And when you're alone, there's a very good chance\nyou'll meet things that scare you right out of your pants.",
#  "There are some, down the road between hither and yon,\nthat can scare you so much you won't want to go on.",
#  'But on you will go\nthough the weather be foul.',
#  'On you will go\nthough your enemies prowl.',
#  'On you will go\nthough the Hakken-Kraks howl.',
#  'Onward up many\na frightening creek,\nthough your arms may get sore\nand your sneakers may leak.',
#  "On and on you will hike,\nAnd I know you'll hike far\nand face up to your problems\nwhatever they are.",
#  "You'll get mixed up, of course,\nas you already know.",
#  "You'll get mixed up\nwith many strange birds as you go.",
#  'So be sure when you step.',
#  "Step with care and great tact\nand remember that Life's\na Great Balancing Act.",
#  'Just never foget to be dexterous and deft.',
#  'And never mix up your right foot with your left.',
#  'And will you succeed?',
#  'Yes!',
#  'You will, indeed!',
#  '(98 and 3/4 percent guaranteed.)',
#  "KID, YOU'LL MOVE MOUNTAINS!",
#  "So...\nbe your name Buxbaum or Bixby or Bray\nor Mordecai Ali Van Allen O'Shea,\nYou're off the Great Places!",
#  'Today is your day!',
#  'Your mountain is waiting.',
#  'So...get on your way!']

# %%
# 3 Important Algorithm: score the sentences
sentence_scores = _score_sentences(sentences, freq_table)
sentence_scores
# Out:
# {'Congratula': 11,
#  'Today is y': 8,
#  "You're off": 6,
#  'You have b': 10,
#  'You have f': 10,
#  'You can st': 8,
#  "You're on ": 13,
#  'And you kn': 10,
#  'And YOU ar': 10,
#  "You'll loo": 13,
#  "Look 'em o": 12,
#  'About some': 9,
#  'With your ': 6,
#  'And you ma': 9,
#  'In that ca': 10,
#  "It's opene": 7,
#  'Out there ': 5,
#  'And then t': 12,
#  "Don't stew": 19,
#  'Just go ri': 19,
#  "You'll sta": 17,
#  'OH!': 11,
#  'THE PLACES': 13,
#  "You'll be ": 8,
#  "You'll joi": 9,
#  "You won't ": 12,
#  "You'll pas": 7,
#  'Wherever y': 13,
#  'Except whe': 13,
#  'Because, s': 17,
#  "I'm sorry ": 6,
#  'You can ge': 4,
#  'And your g': 10,
#  "You'll com": 9,
#  'And the ch': 10,
#  'And when y': 8,
#  'Un-slumpin': 10,
#  'You will c': 6,
#  'Some windo': 15,
#  'But mostly': 13,
#  'A place yo': 3,
#  'Do you dar': 4,
#  'How much c': 3,
#  'And IF you': 9,
#  'Or, maybe,': 8,
#  'Or go arou': 3,
#  "Simple it'": 6,
#  'The Waitin': 9,
#  'Waiting fo': 2,
#  'Everyone i': 20,
#  'NO!': 11,
#  "That's not": 4,
#  'Somehow yo': 6,
#  'With banne': 9,
#  'Ready for ': 10,
#  'Ready beca': 4,
#  'Oh, the pl': 15,
#  'There is f': 3,
#  'There are ': 6,
#  'And the ma': 4,
#  'Fame!': 11,
#  "I'm afraid": 8,
#  'Games you ': 9,
#  'All Alone!': 8,
#  'Whether yo': 8,
#  'But on you': 8,
#  'On you wil': 11,
#  'Onward up ': 7,
#  'On and on ': 6,
#  "You'll get": 10,
#  'So be sure': 10,
#  'Step with ': 5,
#  'Just never': 8,
#  'And never ': 7,
#  'And will y': 1,
#  'Yes!': 12,
#  'You will, ': 13,
#  '(98 and 3/': 9,
#  "KID, YOU'L": 14,
#  'So...\nbe y': 7,
#  'Your mount': 16,
#  'So...get o': 14}

# %%
# 4 Find the threshold
threshold = _find_average_score(sentence_scores)
threshold
# Out:
# 9

# %%
# 5 Important Algorithm: Generate the summary
summary = _generate_summary(sentences, sentence_scores, 1.5 * threshold)

print(summary)
# Out:
#  Don't stew. Just go right along. You'll start happening too. Because, sometimes, you won't. Some windows are lighted. Everyone is just waiting. Everyone is just waiting. Oh, the places you'll go! KID, YOU'LL MOVE MOUNTAINS! Your mountain is waiting. So...get on your way!
