# %%
import pandas as pd
import numpy as np
import altair as alt
from textblob import TextBlob

# %% [markdown]
# ### Amazon Alexa Reviews Dataset
#
# This data was extracted from Amazon and made available at [Kaggle](https://www.kaggle.com/sid321axn/amazon-alexa-reviews).
#
# This dataset consists of a nearly 3000 Amazon customer reviews (input text), star ratings, date of review, variant and feedback of various amazon Alexa products like Alexa Echo, Echo dots, and Alexa Firesticks.

# %%
data = pd.read_csv('data/amazon_alexa.tsv', delimiter='\t')
data.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %% [markdown]
# - Using TextBlob count the number of words in each review, put the results in a new column `words`
# - Is there a correlation between the length of the review and its rating? Use altair to plot a scatterplot
# - Using TextBlob extract the nouns (in a list) of each review, put the results in a new column `nouns`
# - Let us create a high-level summary of review content per rating. Combine the `nouns` per rating. **HINT: you can use groupby then sum to combine lists**
# - Next, convert each list (of a rating) to a dictionary with keys being words and values are the counts. Order by values descending
# - Compare ratings 1 and 5 any notable differences?

# %%
data['words'] = data.verified_reviews.apply(lambda review: len(TextBlob(review).words))

# %%
np.corrcoef(data.rating, data.words)
# Out:
# array([[ 1.        , -0.19027298],
#        [-0.19027298,  1.        ]])

# %%
alt.Chart(data).mark_point().encode(x='words', y='rating')
# Out:
# alt.Chart(...)

# %%
def extract_nouns(sentence):
    blob = TextBlob(sentence)
    return [word.lower() for word, pos in blob.tags if pos.startswith('NN')]

# %%
data['nouns'] = data.verified_reviews.apply(extract_nouns)

# %%
data.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback  words  \
# 0                                      Love my Echo!         1      3
# 1                                          Loved it!         1      2
# 2  Sometimes while playing a game, you can answer...         1     38
# 3  I have had a lot of fun with this thing. My 4 ...         1     34
# 4                                              Music         1      1
#
#                                                nouns
# 0                                             [echo]
# 1                                                 []
# 2              [game, question, alexa, lights, home]
# 3  [lot, fun, thing, learns, dinosaurs, i, lights...
# 4                                                 []

# %%
summaries = data.groupby('rating').nouns.sum()
summaries
# Out:
# rating
# 1    [features, stopped, weeks, commands, fun, alex...
# 2    [siri, fact, siri, alexa, need, household, bar...
# 3    [cellphone, features, ipad, use, alarm, r, dea...
# 4    [game, question, alexa, lights, home, echo, fa...
# 5    [echo, lot, fun, thing, learns, dinosaurs, i, ...
# Name: nouns, dtype: object

# %%
def word_freq(list_of_words):
    return pd.Series(list_of_words).value_counts().to_dict()

# %%
summary_freq = summaries.apply(word_freq)
summary_freq
# Out:
# rating
# 1    {'amazon': 40, 'echo': 38, 'dot': 26, 'device'...
# 2    {'alexa': 33, 'echo': 29, 'device': 29, 'music...
# 3    {'alexa': 51, 'echo': 44, 'speaker': 30, 'dot'...
# 4    {'echo': 125, 'alexa': 112, 'music': 100, 'spe...
# 5    {'echo': 441, 'alexa': 375, 'music': 370, 'sou...
# Name: nouns, dtype: object

# %%
summary_freq[1]
# Out:
# {'amazon': 40,
#  'echo': 38,
#  'dot': 26,
#  'device': 25,
#  'product': 25,
#  't': 23,
#  'time': 19,
#  'alexa': 18,
#  'screen': 18,
#  'thing': 16,
#  'phone': 13,
#  '’': 13,
#  'months': 13,
#  'app': 12,
#  'money': 11,
#  'speaker': 11,
#  'way': 11,
#  'item': 9,
#  'home': 9,
#  'i': 9,
#  'nothing': 8,
#  'work': 8,
#  'things': 8,
#  'spot': 8,
#  'devices': 8,
#  'music': 8,
#  'sound': 7,
#  'question': 7,
#  'wifi': 7,
#  'bluetooth': 7,
#  'show': 7,
#  'cards': 6,
#  'customer': 6,
#  'bulb': 6,
#  'problems': 6,
#  'hue': 6,
#  'hub': 6,
#  'connection': 6,
#  'day': 6,
#  'features': 6,
#  'cycle': 6,
#  'anything': 6,
#  'light': 6,
#  'times': 6,
#  'unit': 6,
#  'video': 5,
#  'service': 5,
#  'clock': 5,
#  'try': 5,
#  'piece': 5,
#  'number': 5,
#  'bridge': 5,
#  'hours': 5,
#  'one': 5,
#  'lights': 5,
#  'voice': 5,
#  'repair': 5,
#  '*': 5,
#  'garbage': 5,
#  'minutes': 4,
#  '”': 4,
#  'waste': 4,
#  'radio': 4,
#  'problem': 4,
#  'week': 4,
#  'questions': 4,
#  'days': 4,
#  'volume': 4,
#  'weeks': 4,
#  'stopped': 4,
#  'jack': 4,
#  'warranty': 4,
#  'software': 4,
#  'instructions': 4,
#  'firmware': 4,
#  'support': 4,
#  'issues': 4,
#  '....': 4,
#  'do': 4,
#  'use': 4,
#  'return': 4,
#  'alexi': 4,
#  'fire': 3,
#  'experience': 3,
#  '..': 3,
#  'mode': 3,
#  'units': 3,
#  'stars': 3,
#  'something': 3,
#  'everything': 3,
#  'trouble': 3,
#  'night': 3,
#  'stops': 3,
#  'spam': 3,
#  'didn': 3,
#  'price': 3,
#  'cheap': 3,
#  'setting': 3,
#  'order': 3,
#  'part': 3,
#  'apple': 3,
#  'internet': 3,
#  'half': 3,
#  'quality': 3,
#  'certified': 3,
#  'package': 3,
#  'language': 3,
#  'photo': 3,
#  'deal': 3,
#  'application': 3,
#  'reminders': 3,
#  'great': 3,
#  's': 3,
#  'philips': 3,
#  'family': 3,
#  'adapter': 3,
#  'roku': 3,
#  'reviews': 3,
#  'couple': 3,
#  'dont': 3,
#  'prime': 3,
#  'power': 3,
#  'plug': 3,
#  'audio': 3,
#  'people': 3,
#  'works': 3,
#  'stick': 3,
#  'command': 3,
#  'ai': 2,
#  'buld': 2,
#  'doesn': 2,
#  'ad': 2,
#  'clue': 2,
#  'im': 2,
#  'zigbee': 2,
#  'fan': 2,
#  'none': 2,
#  'buzzing': 2,
#  'network': 2,
#  'nightstand': 2,
#  'reception': 2,
#  'everytime': 2,
#  'newsflash': 2,
#  'does': 2,
#  'purchases': 2,
#  'sprint': 2,
#  'interference': 2,
#  'stage': 2,
#  'kind': 2,
#  'month': 2,
#  'tablet': 2,
#  'value': 2,
#  'crap': 2,
#  'reboots': 2,
#  'someone': 2,
#  'automation': 2,
#  'room': 2,
#  'top': 2,
#  'difference': 2,
#  'same': 2,
#  'reset': 2,
#  'plus': 2,
#  'fun': 2,
#  'size': 2,
#  'sister': 2,
#  'dots': 2,
#  'recognition': 2,
#  'brand': 2,
#  'box': 2,
#  'refurbished': 2,
#  'nest': 2,
#  'batteries': 2,
#  'customers': 2,
#  'second': 2,
#  'items': 2,
#  'gen': 2,
#  'response': 2,
#  'emoji': 2,
#  'bedroom': 2,
#  'bare': 2,
#  'range': 2,
#  'all': 2,
#  'bug': 2,
#  'excitement': 2,
#  'havent': 2,
#  'job': 2,
#  'fact': 2,
#  '......': 2,
#  'hour': 2,
#  'bought': 2,
#  'firestick': 2,
#  'got': 2,
#  'help': 2,
#  'shows': 2,
#  'house': 2,
#  'bulbs': 2,
#  'wife': 2,
#  'have': 2,
#  'forces': 2,
#  'facetime': 2,
#  'buy': 2,
#  've': 2,
#  'face': 2,
#  'issue': 2,
#  'membership': 2,
#  'tv': 2,
#  'pound': 2,
#  'efforts': 2,
#  'pointless': 2,
#  'year': 2,
#  'to': 2,
#  'refund': 2,
#  'difficulty': 2,
#  'answer': 2,
#  'cord': 2,
#  'thought': 2,
#  'account': 2,
#  'my': 2,
#  'middle': 2,
#  'youtube': 2,
#  'orange': 2,
#  'homescreen': 2,
#  'wall': 2,
#  'access': 2,
#  'commands': 2,
#  'minimum': 2,
#  'videos': 2,
#  'seems': 2,
#  'connected': 2,
#  'techie': 2,
#  'playlist': 2,
#  'advertising': 2,
#  'speakers': 2,
#  'reason': 2,
#  'menu': 2,
#  'wireless': 1,
#  'speech': 1,
#  'refunds': 1,
#  'matter': 1,
#  'need': 1,
#  'law': 1,
#  'position': 1,
#  'road': 1,
#  'resolution': 1,
#  'changes': 1,
#  'opinion': 1,
#  'distraction': 1,
#  'settins': 1,
#  'articles': 1,
#  'bass': 1,
#  'asap': 1,
#  'cups': 1,
#  'information': 1,
#  'assistance': 1,
#  'permanently': 1,
#  'isn': 1,
#  'logo': 1,
#  'sucks': 1,
#  'screens': 1,
#  'hundreds': 1,
#  'displays': 1,
#  'fixing': 1,
#  'solution': 1,
#  'never': 1,
#  'technology': 1,
#  'espanol': 1,
#  'bathroom': 1,
#  'disconnects': 1,
#  'attempt': 1,
#  'monitor': 1,
#  'depth': 1,
#  'users': 1,
#  'degree': 1,
#  'echos': 1,
#  'thongs': 1,
#  'technicians': 1,
#  'except': 1,
#  'hard': 1,
#  'harvard': 1,
#  'tool': 1,
#  'cant': 1,
#  'till': 1,
#  'standards': 1,
#  'cam': 1,
#  'junk': 1,
#  'baby': 1,
#  'plenty': 1,
#  'products': 1,
#  'option': 1,
#  'trending': 1,
#  'content': 1,
#  'services': 1,
#  'office': 1,
#  'on/off': 1,
#  'eyes': 1,
#  'really': 1,
#  'annoying': 1,
#  'habla': 1,
#  'monthly': 1,
#  'area': 1,
#  'eh': 1,
#  'af': 1,
#  'basic': 1,
#  'questions.it': 1,
#  'games': 1,
#  'industry': 1,
#  'tech': 1,
#  'card': 1,
#  'bar': 1,
#  'spending': 1,
#  'dim': 1,
#  'period': 1,
#  'slideshow': 1,
#  'avail': 1,
#  'ones': 1,
#  'and': 1,
#  'luck': 1,
#  'funny': 1,
#  'feet': 1,
#  'nd': 1,
#  'while': 1,
#  'connecting': 1,
#  'years': 1,
#  'buyer': 1,
#  'colors': 1,
#  'router': 1,
#  'functions': 1,
#  'pain': 1,
#  'please': 1,
#  'quit': 1,
#  'm': 1,
#  "'clock": 1,
#  'trust': 1,
#  'fixes': 1,
#  're-set': 1,
#  'device.right': 1,
#  'kitchen': 1,
#  'collectors': 1,
#  'birth': 1,
#  'set': 1,
#  'page.i': 1,
#  'program': 1,
#  'bottom': 1,
#  'brought': 1,
#  'nuts': 1,
#  'message': 1,
#  "'things": 1,
#  'timers': 1,
#  'voices': 1,
#  'hd': 1,
#  'groups': 1,
#  'amazon/zigbee': 1,
#  'movies': 1,
#  'functionality': 1,
#  'dissatisfaction': 1,
#  'default': 1,
#  'galaxy': 1,
#  'upsetting': 1,
#  'skill': 1,
#  'subscription': 1,
#  'updates': 1,
#  'enough': 1,
#  'books': 1,
#  'requests': 1,
#  'form': 1,
#  '=y': 1,
#  'contents': 1,
#  'knowledge': 1,
#  'potential': 1,
#  'creapy': 1,
#  'repairs': 1,
#  'member': 1,
#  'god': 1,
#  'water': 1,
#  'fee': 1,
#  'lack': 1,
#  'troubleshooting': 1,
#  'tried': 1,
#  'super': 1,
#  'so': 1,
#  'date': 1,
#  'research': 1,
#  '%': 1,
#  'restart': 1,
#  'thousands': 1,
#  'zzzz': 1,
#  'sentence': 1,
#  'future': 1,
#  'accounts': 1,
#  'glad': 1,
#  'smart': 1,
#  'nightmare': 1,
#  'semi': 1,
#  'looses': 1,
#  'store': 1,
#  'alexas': 1,
#  'life': 1,
#  'network/technology': 1,
#  'purchase': 1,
#  'fairness': 1,
#  'no': 1,
#  'stuff': 1,
#  'mids': 1,
#  'move': 1,
#  'glitch': 1,
#  'disaster': 1,
#  'lifetime': 1,
#  'thank': 1,
#  'themes': 1,
#  'dollar': 1,
#  'replacement': 1,
#  'back': 1,
#  'feature': 1,
#  'name': 1,
#  'pictures': 1,
#  'discount': 1,
#  'not': 1,
#  'ca': 1,
#  'figure': 1,
#  'nobody': 1,
#  'interaction': 1,
#  'americans': 1,
#  'often': 1,
#  'apps': 1,
#  'heard': 1,
#  'protocol': 1,
#  'idea': 1,
#  'blue': 1,
#  'plugs': 1,
#  'bucks': 1,
#  'advance': 1,
#  'button': 1,
#  'doesnt': 1,
#  'answers': 1,
#  'a': 1,
#  'echo/dot': 1,
#  'control': 1,
#  'action': 1,
#  'living': 1,
#  'broken': 1,
#  'alarm': 1,
#  'conversations': 1,
#  'first': 1,
#  'extender': 1,
#  'list': 1,
#  'star': 1,
#  'billboard': 1,
#  'skype': 1,
#  'easier.i': 1,
#  'generation': 1,
#  'weather': 1,
#  'convenient': 1,
#  'mine': 1,
#  'sent': 1,
#  'lines': 1,
#  'alerts': 1,
#  'sling': 1,
#  'site': 1,
#  'connect': 1,
#  'friend': 1,
#  'noise': 1,
#  'but': 1,
#  'irritating': 1,
#  'benefit': 1,
#  'heads': 1,
#  'advertisement': 1,
#  'chat': 1,
#  'pass': 1,
#  'get': 1,
#  'example': 1,
#  'sounds': 1,
#  'hasn': 1,
#  'pair': 1,
#  'buttons': 1,
#  'rarity': 1,
#  'of': 1,
#  'case': 1,
#  'purchases.i': 1,
#  'option.moreover': 1,
#  'mark': 1,
#  'one.2': 1,
#  'news': 1,
#  'directions': 1,
#  'ecosystem': 1,
#  'promotion': 1,
#  'function': 1,
#  'them': 1,
#  'calls': 1,
#  'chromebook': 1,
#  'wi-fi': 1,
#  'suggestions': 1,
#  'rep': 1,
#  'parents': 1,
#  'shape': 1,
#  'point': 1,
#  's8': 1,
#  'lightbulb': 1,
#  'glitching': 1,
#  'been': 1,
#  'online': 1,
#  'lamps': 1,
#  'marketing': 1,
#  'texas': 1,
#  'fail': 1,
#  'party': 1,
#  'inline': 1,
#  'followed': 1,
#  'review': 1,
#  'accent': 1,
#  'grandparents': 1,
#  'wikipedia': 1,
#  'tv.i': 1,
#  'color': 1,
#  'step': 1,
#  'words': 1,
#  'grandmother': 1,
#  'numb': 1,
#  'north': 1,
#  'dust': 1,
#  'son': 1,
#  'boss': 1,
#  'switches': 1,
#  'lurking': 1,
#  'line': 1,
#  'upgrades': 1,
#  'seconds': 1,
#  'performing': 1,
#  'steps': 1,
#  'setup': 1,
#  'accesss': 1,
#  'amazons\u200b': 1,
#  'tin': 1,
#  'intercom': 1,
#  'fine': 1,
#  'scroll': 1}

# %%
summary_freq[5]
# Out:
# {'echo': 441,
#  'alexa': 375,
#  'music': 370,
#  'sound': 179,
#  'product': 166,
#  'dot': 160,
#  'home': 143,
#  'great': 139,
#  'amazon': 121,
#  'speaker': 117,
#  'works': 114,
#  'day': 113,
#  'time': 109,
#  'fun': 107,
#  'device': 104,
#  'room': 101,
#  'things': 95,
#  'house': 87,
#  'everything': 85,
#  'show': 85,
#  'quality': 85,
#  'thing': 84,
#  'weather': 84,
#  'prime': 83,
#  'tv': 82,
#  'devices': 80,
#  'love': 78,
#  't': 72,
#  'spot': 68,
#  'easy': 67,
#  'lights': 67,
#  'alarm': 65,
#  'clock': 65,
#  'bedroom': 61,
#  'price': 57,
#  'screen': 54,
#  'hub': 53,
#  'voice': 53,
#  'family': 49,
#  '’': 48,
#  'use': 47,
#  'phone': 47,
#  'purchase': 46,
#  'video': 46,
#  'news': 46,
#  'lot': 45,
#  'dots': 45,
#  'fire': 44,
#  'stick': 44,
#  'kitchen': 42,
#  'speakers': 41,
#  'plus': 41,
#  'features': 40,
#  'i': 39,
#  'app': 36,
#  'questions': 36,
#  'information': 36,
#  'gift': 35,
#  'item': 34,
#  'size': 34,
#  'songs': 34,
#  'setup': 33,
#  'way': 33,
#  'kids': 33,
#  'feature': 32,
#  'morning': 32,
#  'daughter': 31,
#  'bought': 30,
#  'wife': 28,
#  'something': 28,
#  'shows': 27,
#  'night': 26,
#  'work': 26,
#  'radio': 25,
#  'movies': 25,
#  'generation': 25,
#  'anything': 25,
#  'life': 24,
#  'volume': 24,
#  'perfect': 24,
#  'games': 24,
#  'smart': 24,
#  'living': 24,
#  'cable': 24,
#  'addition': 24,
#  'son': 23,
#  'light': 23,
#  'thank': 23,
#  'problems': 23,
#  'awesome': 23,
#  'song': 23,
#  'issues': 23,
#  'bluetooth': 22,
#  'part': 22,
#  'one': 22,
#  'skills': 22,
#  'stuff': 22,
#  'commands': 22,
#  'husband': 22,
#  'list': 21,
#  'alarms': 21,
#  'buy': 21,
#  'options': 21,
#  '..': 21,
#  'nice': 21,
#  'fact': 20,
#  'apps': 20,
#  'play': 20,
#  'year': 20,
#  'office': 19,
#  'lists': 19,
#  'timer': 19,
#  'firestick': 19,
#  'products': 19,
#  'technology': 19,
#  '....': 19,
#  'updates': 18,
#  'bulbs': 18,
#  'capabilities': 18,
#  'command': 18,
#  'unit': 18,
#  'system': 17,
#  'bit': 17,
#  'instructions': 17,
#  'echos': 17,
#  'set': 17,
#  'ease': 17,
#  '”': 17,
#  'money': 17,
#  'deal': 17,
#  'order': 16,
#  'camera': 16,
#  'amazing': 16,
#  'ability': 16,
#  'brand': 16,
#  'recipes': 16,
#  'problem': 16,
#  'timers': 16,
#  'friend': 16,
#  'sounds': 16,
#  'lyrics': 16,
#  'gen': 15,
#  'lots': 15,
#  'cameras': 15,
#  'remote': 15,
#  'internet': 15,
#  'thermostat': 15,
#  'super': 15,
#  'books': 14,
#  'pandora': 14,
#  'everyone': 14,
#  'while': 14,
#  'assistant': 14,
#  'rooms': 13,
#  'google': 13,
#  'nothing': 13,
#  'got': 13,
#  'ones': 13,
#  'jokes': 13,
#  'cool': 13,
#  'thanks': 13,
#  'mom': 13,
#  'access': 13,
#  'looks': 13,
#  'plug': 13,
#  'entertainment': 13,
#  'sale': 13,
#  'bulb': 13,
#  'help': 13,
#  'reminders': 13,
#  'door': 13,
#  'hue': 12,
#  's': 12,
#  'computer': 12,
#  'uses': 12,
#  'philips': 12,
#  'traffic': 12,
#  'week': 12,
#  'people': 12,
#  'plugs': 12,
#  'spotify': 12,
#  'has': 12,
#  'control': 12,
#  'mother': 12,
#  'netflix': 11,
#  'years': 11,
#  'option': 11,
#  'difference': 11,
#  'dad': 11,
#  'minutes': 11,
#  'trouble': 11,
#  'security': 11,
#  'group': 11,
#  'future': 11,
#  'parents': 11,
#  'calls': 11,
#  'etc': 11,
#  'cell': 11,
#  'plays': 11,
#  'base': 11,
#  'kasa': 10,
#  'movie': 10,
#  'stations': 10,
#  'hours': 10,
#  'someone': 10,
#  'words': 10,
#  'friends': 10,
#  'ca': 10,
#  '“': 10,
#  'best': 9,
#  'gadget': 9,
#  'grocery': 9,
#  'functions': 9,
#  'days': 9,
#  'wifi': 9,
#  'drop': 9,
#  'star': 9,
#  'complaints': 9,
#  'channels': 9,
#  'toy': 9,
#  'videos': 9,
#  'youtube': 9,
#  'bose': 9,
#  'nightstand': 9,
#  'birthday': 9,
#  'piece': 9,
#  'm': 9,
#  'value': 9,
#  'times': 9,
#  'experience': 9,
#  'shopping': 9,
#  'weeks': 9,
#  'couple': 9,
#  'household': 9,
#  'bedside': 8,
#  'issue': 8,
#  'need': 8,
#  'clarity': 8,
#  'interface': 8,
#  'look': 8,
#  'display': 8,
#  'recommend': 8,
#  'ways': 8,
#  'have': 8,
#  'world': 8,
#  'job': 8,
#  'hands': 8,
#  'briefing': 8,
#  'it': 8,
#  'skill': 8,
#  'tech': 8,
#  'picture': 8,
#  'automation': 8,
#  'alexia': 8,
#  'ring': 8,
#  'programs': 8,
#  'lamp': 8,
#  'installation': 8,
#  'request': 8,
#  'service': 8,
#  'range': 7,
#  'packaging': 7,
#  'penny': 7,
#  'notifications': 7,
#  'condition': 7,
#  'trek': 7,
#  'tool': 7,
#  'wireless': 7,
#  'version': 7,
#  'fine': 7,
#  'lol': 7,
#  'account': 7,
#  'others': 7,
#  'kind': 7,
#  'anyone': 7,
#  'stand': 7,
#  'box': 7,
#  'number': 7,
#  'touch': 7,
#  'process': 7,
#  'cloud': 6,
#  'equipment': 6,
#  'settings': 6,
#  'course': 6,
#  'counter': 6,
#  'watch': 6,
#  'power': 6,
#  'shipping': 6,
#  'replacement': 6,
#  'call': 6,
#  'today': 6,
#  'convenient': 6,
#  'functionality': 6,
#  'tap': 6,
#  'color': 6,
#  'charm': 6,
#  'get': 6,
#  'doorbell': 6,
#  'intercom': 6,
#  'deck': 6,
#  'classroom': 6,
#  'apple': 6,
#  'trivia': 6,
#  'name': 6,
#  'simple': 6,
#  'new': 6,
#  'and': 6,
#  'savvy': 6,
#  'school': 6,
#  'info': 6,
#  'sister': 6,
#  'grandkids': 6,
#  'excellent': 6,
#  'question': 6,
#  'homework': 6,
#  'bathroom': 6,
#  'loads': 6,
#  'cam': 6,
#  'was': 6,
#  'calendar': 6,
#  'cord': 6,
#  'response': 6,
#  'guy': 6,
#  'wait': 6,
#  'items': 6,
#  'tunes': 6,
#  'playlists': 6,
#  'podcasts': 6,
#  'chat': 6,
#  '%': 6,
#  'lighting': 6,
#  '*': 6,
#  'program': 6,
#  'types': 6,
#  'makes': 6,
#  'directions': 6,
#  'glad': 6,
#  'beginning': 6,
#  'my': 6,
#  'floor': 6,
#  'improvement': 6,
#  'father': 6,
#  'microphone': 6,
#  'grandchildren': 6,
#  'cost': 6,
#  'convenience': 5,
#  'bass': 5,
#  'playlist': 5,
#  'tell': 5,
#  'complaint': 5,
#  'routine': 5,
#  'kindle': 5,
#  'story': 5,
#  'audio': 5,
#  'function': 5,
#  'package': 5,
#  'buttons': 5,
#  'support': 5,
#  'privacy': 5,
#  'stories': 5,
#  'person': 5,
#  'lamps': 5,
#  'custom': 5,
#  'blast': 5,
#  'discount': 5,
#  'button': 5,
#  'pool': 5,
#  'capability': 5,
#  'side': 5,
#  'bonus': 5,
#  'stereo': 5,
#  'fault': 5,
#  'choices': 5,
#  'mini': 5,
#  'idea': 5,
#  'selection': 5,
#  'cute': 5,
#  'artist': 5,
#  'speak': 5,
#  'design': 5,
#  'appointments': 5,
#  'pleasure': 5,
#  'moment': 5,
#  'schedule': 5,
#  'que': 5,
#  'expectations': 5,
#  'upstairs': 5,
#  'bed': 5,
#  'highly': 5,
#  'haha': 4,
#  'controls': 4,
#  'go': 4,
#  'locks': 4,
#  'reminder': 4,
#  'desk': 4,
#  'test': 4,
#  '/': 4,
#  'l': 4,
#  'trailers': 4,
#  'variety': 4,
#  'downstairs': 4,
#  'camelot': 4,
#  'wi-fi': 4,
#  'favorite': 4,
#  'reason': 4,
#  'guest': 4,
#  'cd': 4,
#  'enjoyment': 4,
#  'wow': 4,
#  'connection': 4,
#  'requests': 4,
#  'she': 4,
#  'breeze': 4,
#  'reviews': 4,
#  'shop': 4,
#  ']': 4,
#  'in': 4,
#  'location': 4,
#  'face': 4,
#  'talk': 4,
#  'sleep': 4,
#  'sense': 4,
#  've': 4,
#  'll': 4,
#  'answer': 4,
#  'area': 4,
#  'watching': 4,
#  'reports': 4,
#  'all': 4,
#  'television': 4,
#  'man': 4,
#  'children': 4,
#  'right': 4,
#  'iphone': 4,
#  'source': 4,
#  'rocks': 4,
#  'simply': 4,
#  'member': 4,
#  'line': 4,
#  'homes': 4,
#  'battery': 4,
#  'refurb': 4,
#  'hit': 4,
#  'to': 4,
#  'possibilities': 4,
#  'wakes': 4,
#  'contact': 4,
#  'understands': 4,
#  'step': 4,
#  'wake': 4,
#  'accent': 4,
#  'roku': 4,
#  'purchases': 4,
#  'doesn': 4,
#  'awhile': 4,
#  'does': 4,
#  'book': 4,
#  'audiobook': 4,
#  'jazz': 4,
#  'knowledge': 4,
#  '.....': 4,
#  'delivery': 4,
#  'yesterday': 4,
#  'routines': 4,
#  'yard': 4,
#  'im': 4,
#  'electronics': 4,
#  'type': 4,
#  'comfort': 3,
#  'versatile': 3,
#  'forward': 3,
#  'concerns': 3,
#  'iheartradio': 3,
#  'meditation': 3,
#  'companion': 3,
#  'turn': 3,
#  'rate': 3,
#  'es': 3,
#  'y': 3,
#  'material': 3,
#  'company': 3,
#  'simpler': 3,
#  'la': 3,
#  'spots': 3,
#  'absolutely': 3,
#  'described': 3,
#  'data': 3,
#  'matter': 3,
#  'center': 3,
#  'mine': 3,
#  'attention': 3,
#  'dislikes': 3,
#  'lag': 3,
#  'paper': 3,
#  'this': 3,
#  'a+': 3,
#  'contacts': 3,
#  'systems': 3,
#  'android': 3,
#  'user': 3,
#  'events': 3,
#  'holder': 3,
#  'memory': 3,
#  'sooner': 3,
#  'download': 3,
#  'cnn': 3,
#  'error': 3,
#  'integration': 3,
#  'did': 3,
#  'place': 3,
#  'management': 3,
#  'fixtures': 3,
#  'downside': 3,
#  'thinking': 3,
#  'footprint': 3,
#  'arlo': 3,
#  'decor': 3,
#  'ac': 3,
#  'regrets': 3,
#  'su': 3,
#  'glitches': 3,
#  'whenever': 3,
#  'availability': 3,
#  'playing': 3,
#  'lives': 3,
#  'good': 3,
#  'don': 3,
#  'fast': 3,
#  'bt': 3,
#  'answers': 3,
#  'cooking': 3,
#  'sets': 3,
#  'apartment': 3,
#  'network': 3,
#  'refurbished': 3,
#  'photos': 3,
#  'discovery': 3,
#  'off': 3,
#  'water': 3,
#  'parts': 3,
#  'hell': 3,
#  'blue': 3,
#  'cent': 3,
#  'iheart': 3,
#  'learn': 3,
#  'phones': 3,
#  'resolution': 3,
#  'wall': 3,
#  'anytime': 3,
#  'boyfriend': 3,
#  'law': 3,
#  'so': 3,
#  'louder': 3,
#  'improvements': 3,
#  'benefits': 3,
#  'word': 3,
#  'chromecast': 3,
#  'thunderstorm': 3,
#  'wish': 3,
#  'responds': 3,
#  'audiophile': 3,
#  'versatility': 3,
#  'station': 3,
#  'fan': 3,
#  'trial': 3,
#  'ai': 3,
#  'phase': 3,
#  'its': 3,
#  'customization': 3,
#  'users': 3,
#  'treadmill': 3,
#  'aspects': 3,
#  'met': 3,
#  'message': 3,
#  'secretary': 3,
#  'turns': 3,
#  'excelente': 3,
#  'scheduling': 3,
#  '+': 3,
#  'eeaanh': 3,
#  'middle': 3,
#  'echoes': 3,
#  'switches': 3,
#  'warehouse': 3,
#  'software': 3,
#  'likes': 3,
#  'usage': 3,
#  'connect': 3,
#  'directv': 3,
#  'eyes': 3,
#  'default': 3,
#  'but': 3,
#  'listening': 3,
#  'mood': 3,
#  'italy': 2,
#  'abilities': 2,
#  'imusic': 2,
#  'guess': 2,
#  'metro': 2,
#  'title': 2,
#  'none': 2,
#  'grandson': 2,
#  'things.it': 2,
#  'sm': 2,
#  'amounts': 2,
#  'ass': 2,
#  'pics': 2,
#  'adapter': 2,
#  'lullaby': 2,
#  'rubber': 2,
#  'listen': 2,
#  'vacations': 2,
#  'replaced': 2,
#  'alot': 2,
#  'weight': 2,
#  'showman': 2,
#  'exchange': 2,
#  'greatest': 2,
#  'curve': 2,
#  'boombox': 2,
#  'bezos': 2,
#  'unique': 2,
#  'prize': 2,
#  'u-tube': 2,
#  'space': 2,
#  'nights': 2,
#  'invention': 2,
#  'estar': 2,
#  'subscription': 2,
#  'grandsons': 2,
#  'voila': 2,
#  'vehicle': 2,
#  'keyboard': 2,
#  'llegó': 2,
#  'paroduct': 2,
#  'age': 2,
#  'askes': 2,
#  'genre': 2,
#  'link': 2,
#  'fathers': 2,
#  'form': 2,
#  '—': 2,
#  'bottom': 2,
#  '=': 2,
#  'loves': 2,
#  'month': 2,
#  'ecoo': 2,
#  'yes': 2,
#  'estudio': 2,
#  'set-up': 2,
#  'fun.it': 2,
#  'goodies': 2,
#  'tekkie': 2,
#  'skype': 2,
#  'had': 2,
#  'calmer': 2,
#  'funciones': 2,
#  'ask': 2,
#  'offers': 2,
#  'learns': 2,
#  'rest': 2,
#  'kinds': 2,
#  'building': 2,
#  'grandmother': 2,
#  'changes': 2,
#  'tooth': 2,
#  'audible': 2,
#  'wealth': 2,
#  'vez': 2,
#  'woofers': 2,
#  'multi': 2,
#  'everyday': 2,
#  'buffet': 2,
#  'ordering': 2,
#  'atrás': 2,
#  'pamphlet': 2,
#  'tons': 2,
#  'performance': 2,
#  'voices': 2,
#  'changer': 2,
#  'like': 2,
#  'rain': 2,
#  'colors': 2,
#  'itunes': 2,
#  'definition': 2,
#  'needs': 2,
#  'argue': 2,
#  'places': 2,
#  'granddaughter': 2,
#  'conferencing': 2,
#  'anypod': 2,
#  'digitol': 2,
#  'speed': 2,
#  'tells': 2,
#  'herself': 2,
#  'speaker/stereo': 2,
#  'champ': 2,
#  'esta': 2,
#  'any': 2,
#  'lg': 2,
#  'quiz': 2,
#  'nois': 2,
#  'inexperience': 2,
#  'start': 2,
#  'first': 2,
#  'pencil': 2,
#  'afternoon': 2,
#  'spark': 2,
#  'dancing': 2,
#  'task': 2,
#  'is': 2,
#  'intercoms': 2,
#  'collection': 2,
#  'links': 2,
#  'members': 2,
#  'think': 2,
#  'thought': 2,
#  'quick': 2,
#  'perdió': 2,
#  'anybody': 2,
#  'wonders': 2,
#  'personality': 2,
#  'domain': 2,
#  'emergency': 2,
#  'choice': 2,
#  'country': 2,
#  'huge': 2,
#  'bible': 2,
#  'password': 2,
#  'genres': 2,
#  'clocks': 2,
#  'blasting': 2,
#  'ceiling': 2,
#  'u': 2,
#  'un': 2,
#  'bells': 2,
#  'recipe': 2,
#  'creepy': 2,
#  'bolt': 2,
#  'website': 2,
#  'yrs': 2,
#  'names': 2,
#  'soundbar': 2,
#  'demand': 2,
#  'laugh': 2,
#  'care': 2,
#  'ages': 2,
#  'tiempo': 2,
#  'comands': 2,
#  'toda': 2,
#  'humour': 2,
#  'sonos': 2,
#  'comment': 2,
#  'present': 2,
#  'seamless': 2,
#  'king': 2,
#  'heard': 2,
#  'tasha': 2,
#  'serius': 2,
#  't.v': 2,
#  '.i': 2,
#  'fi': 2,
#  'flash': 2,
#  'bill': 2,
#  'seems': 2,
#  'one.it': 2,
#  'countries': 2,
#  'couldn': 2,
#  'doors': 2,
#  'external': 2,
#  'novelty': 2,
#  'socket': 2,
#  'fits': 2,
#  'extras': 2,
#  'patio': 2,
#  'level': 2,
#  'calm': 2,
#  'states': 2,
#  'same': 2,
#  'childhood': 2,
#  'charger': 2,
#  'chance': 2,
#  'pure': 2,
#  'usb': 2,
#  'temps': 2,
#  'visuals': 2,
#  'alcohol': 2,
#  'add': 2,
#  'bills': 2,
#  'bedrooms': 2,
#  'solution': 2,
#  'singing': 2,
#  'expectation': 2,
#  'bff': 2,
#  'christmas': 2,
#  'tower': 2,
#  'site': 2,
#  'plan': 2,
#  'burns': 2,
#  'killer': 2,
#  'fidelity': 2,
#  'enrolment': 2,
#  'review': 2,
#  'chair': 2,
#  'capasity': 2,
#  'supberb': 2,
#  'sucks': 2,
#  'awesome.understands': 2,
#  'dance': 2,
#  '😍': 2,
#  'shape': 2,
#  'minute': 2,
#  'expect': 2,
#  'means': 2,
#  'nite': 2,
#  'mode': 2,
#  'sunroom': 2,
#  'temperature': 2,
#  'plans': 2,
#  'basement': 2,
#  'jimmy': 2,
#  'alex': 2,
#  'paranoid': 2,
#  'no-brainer': 2,
#  'knock': 2,
#  'info.dot': 2,
#  'omg': 2,
#  'sources': 2,
#  'poster': 2,
#  'media': 2,
#  'outlet': 2,
#  'funny': 2,
#  'please': 2,
#  'state': 2,
#  'qvc': 2,
#  'been': 2,
#  'opinion': 2,
#  'handy': 2,
#  'regret': 2,
#  'drivers': 2,
#  'operation': 2,
#  'broadway': 2,
#  'goo': 2,
#  'sin': 2,
#  'grands': 2,
#  'owner': 2,
#  'island': 2,
#  'smarthome': 2,
#  'favorites': 2,
#  'route': 2,
#  'actions': 2,
#  'outlets': 2,
#  'd': 2,
#  'delay': 2,
#  'commute': 2,
#  'hour+': 2,
#  'bridge': 2,
#  'barn': 2,
#  'plenty': 2,
#  'mic': 2,
#  'godsend': 2,
#  'enjoyed': 2,
#  'showering': 2,
#  'ours': 2,
#  'kodi': 2,
#  'sports': 2,
#  'listens': 2,
#  'be': 2,
#  'completely': 2,
#  'breakfast': 2,
#  'nos': 2,
#  'adopters': 2,
#  'cat': 2,
#  'structure': 2,
#  'alone': 2,
#  'phenomenal': 2,
#  'featues': 2,
#  'numbers': 2,
#  'inside': 2,
#  'al': 2,
#  'español': 2,
#  'hora': 2,
#  'as': 2,
#  'medium': 2,
#  'accessories': 2,
#  '😁😁😁😁': 2,
#  'smiths': 2,
#  'cards': 2,
#  'keeper': 2,
#  'expert': 2,
#  'pain': 2,
#  'locations': 2,
#  'tips': 2,
#  'description': 2,
#  'employees': 2,
#  'tablet': 2,
#  'imperfection': 2,
#  'learning': 2,
#  'frustration': 2,
#  'white': 2,
#  'siri': 2,
#  'yr': 2,
#  'múltiples': 2,
#  'gifts': 2,
#  'manufacturers': 2,
#  'con': 2,
#  'wi': 2,
#  'round': 2,
#  'theater': 2,
#  'black': 2,
#  'gender': 2,
#  'note': 2,
#  'exho': 2,
#  'helps': 2,
#  'distance': 2,
#  'ipad': 2,
#  'owners': 2,
#  'briefings': 2,
#  'flashes': 2,
#  'hesitant': 2,
#  'tweeters': 2,
#  'hers': 2,
#  'a.i': 2,
#  'horse': 2,
#  'band': 2,
#  'buyers': 2,
#  'fall': 2,
#  'inteligente': 2,
#  'photo': 2,
#  'months': 2,
#  'forecasts': 2,
#  'nana': 2,
#  'conectado': 2,
#  'vlan': 2,
#  'mind': 2,
#  'anymore': 2,
#  'second': 2,
#  'package—easy': 2,
#  'olor': 2,
#  'pup': 2,
#  'producto': 2,
#  'covers': 2,
#  'cordless': 2,
#  'bucks': 2,
#  'como': 2,
#  'blueprints': 2,
#  'escencia': 2,
#  'adults': 2,
#  '.on': 2,
#  'realizando': 2,
#  'responses': 2,
#  'joke': 2,
#  'hates': 2,
#  'feel': 2,
#  'este': 2,
#  'tricks': 2,
#  'waste': 2,
#  'not': 2,
#  'point': 2,
#  'notification': 2,
#  'bugs': 2,
#  'style': 2,
#  'den': 2,
#  'upgrade': 2,
#  'plane': 2,
#  'vacation': 2,
#  'car': 2,
#  'damage': 2,
#  'enables': 2,
#  'wedding': 2,
#  'bark': 2,
#  'collections': 2,
#  'stairs': 2,
#  'concept': 2,
#  'cover': 2,
#  'shipment': 2,
#  'the': 2,
#  'training': 2,
#  'pc': 2,
#  'thoughts': 2,
#  'benefit': 2,
#  'god': 2,
#  'jack': 2,
#  'third': 2,
#  'choosing': 2,
#  'communication': 2,
#  'wasn': 2,
#  'content': 2,
#  'tales': 2,
#  'uses.sometimes': 2,
#  'may': 2,
#  'investment': 2,
#  'verse': 2,
#  'whistles': 2,
#  'bread': 2,
#  'city': 2,
#  'whats': 2,
#  'dog': 1,
#  'didnt': 1,
#  'folks': 1,
#  ...}
